# %% [markdown]
# Hypothesis 1-The highest contributing ingredients are Sugar,salt,purpose flour
# Hypothesis 2-Dessert occures more frequently amoungst the top 40 time consuming recipes

# %%
#Installing the required packages and libraries
# !pip install gdown
# !python -m spacy download en_core_web_sm
# !pip install nltk
# !pip install wordcloud

from wordcloud import WordCloud
import pandas as pd
import seaborn as sns
import gdown
import spacy
import re
from itertools import chain
import matplotlib.pyplot as plt
import numpy as np
import ast
from itertools import chain
from fractions import Fraction
import unicodedata
# %matplotlib inline
import warnings
from collections import Counter
warnings.filterwarnings("ignore")

# %%
#Importing the first recipe dataset from google drive
url = 'https://drive.google.com/uc?id=1K2J4GryH4OyzFYyjfCeCjbRPNhugb1DH'
output = 'Project_3.csv'
gdown.download(url, output, quiet=False)

df=pd.read_csv("Project_3.csv")
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1K2J4GryH4OyzFYyjfCeCjbRPNhugb1DH
# To: C:\Users\Administrator\Downloads\Project_3.csv
# 100%|██████████| 1.64M/1.64M [00:00<00:00, 19.1MB/s]

# %%
#Importing the second recipe dataset from google drive
url1 = 'https://drive.google.com/uc?id=1MBhfHXuoBZ6YccOuujdcrUEFAw6W__oD'
output1 = 'Project_3_1.csv'
gdown.download(url1, output1, quiet=False)

df2=pd.read_csv("Project_3_1.csv")
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1MBhfHXuoBZ6YccOuujdcrUEFAw6W__oD
# To: C:\Users\Administrator\Downloads\Project_3_1.csv
# 100%|██████████| 94.0k/94.0k [00:00<00:00, 2.75MB/s]

# %%
df
# Out:
#       Unnamed: 0                        recipe_name prep_time cook_time  \
# 0              0           Apple-Cranberry Crostada       NaN       NaN
# 1              1          Apple Pie by Grandma Ople   30 mins     1 hrs
# 2              2        Sarah's Homemade Applesauce   10 mins   15 mins
# 3              3                        Apple Crisp   30 mins   45 mins
# 4              4                  Apple Pie Filling   20 mins   20 mins
# ...          ...                                ...       ...       ...
# 1085        1085                     Date-Nut Balls   15 mins   10 mins
# 1086        1086                       Jamaica Cake       NaN       NaN
# 1087        1087                     Best Hot Sauce   10 mins   20 mins
# 1088        1088               Moist Date Nut Bread   15 mins   50 mins
# 1089        1089  Chef John's Chocolate Energy Bars   15 mins       NaN
#
#          total_time  servings              yield  \
# 0               NaN         8  6 to 8 - servings
# 1     1 hrs 30 mins         8       1 9-inch pie
# 2           25 mins         4                NaN
# 3     1 hrs 15 mins        12    1 9x13-inch pan
# 4     2 hrs 40 mins        40      5 9-inch pies
# ...             ...       ...                ...
# 1085        30 mins        48      4 dozen balls
# 1086            NaN        14  1 - 13x9 inch pan
# 1087        30 mins       100             2 cups
# 1088  1 hrs 35 mins        12    1 9x5-inch loaf
# 1089          3 hrs        12            12 bars
#
#                                             ingredients  \
# 0     3 tablespoons butter, 2 pounds Granny Smith ap...
# 1     8 small Granny Smith apples, or as needed, ½ c...
# 2     4  apples - peeled, cored and chopped, ¾ cup w...
# 3     10 cups all-purpose apples, peeled, cored and ...
# 4     18 cups thinly sliced apples, 3 tablespoons le...
# ...                                                 ...
# 1085  14 tablespoons butter, 1 cup pitted chopped da...
# 1086  2 cups white sugar, 1 ½ cups vegetable oil, 1 ...
# 1087  10  fresh hot chile peppers, stems removed, 1 ...
# 1088  2 ½ cups chopped dates, ¼ cup butter, 1 cup bo...
# 1089  2 cups pitted Medjool dates, roughly chopped, ...
#
#                                              directions  rating  \
# 0     Heat butter in a large skillet over medium-hig...     4.4
# 1     Peel and core apples, then thinly slice. Set a...     4.8
# 2     Combine apples, water, sugar, and cinnamon in ...     4.8
# 3     Preheat the oven to 350 degrees F (175 degrees...     4.7
# 4     Toss apples with lemon juice in a large bowl a...     4.7
# ...                                                 ...     ...
# 1085  Melt butter in a saucepan over medium heat; co...     3.8
# 1086  Mix together sugar, vegetable oil, pecans, flo...     4.6
# 1087  Place peppers, onion, dates, basil, parsley, t...     4.9
# 1088  Preheat the oven to 350 degrees F (175 degrees...     4.5
# 1089  Place cashews, almonds, coconut, dates, cocoa,...     4.8
#
#                                                     url  \
# 0     https://www.allrecipes.com/recipe/76931/apple-...
# 1     https://www.allrecipes.com/recipe/12682/apple-...
# 2     https://www.allrecipes.com/recipe/51301/sarahs...
# 3     https://www.allrecipes.com/recipe/12409/apple-...
# 4     https://www.allrecipes.com/recipe/12681/apple-...
# ...                                                 ...
# 1085  https://www.allrecipes.com/recipe/240653/date-...
# 1086  https://www.allrecipes.com/recipe/7509/jamaica...
# 1087  https://www.allrecipes.com/recipe/242153/best-...
# 1088  https://www.allrecipes.com/recipe/51446/moist-...
# 1089  https://www.allrecipes.com/recipe/254452/chef-...
#
#                                            cuisine_path  \
# 0       /Desserts/Fruit Desserts/Apple Dessert Recipes/
# 1                     /Desserts/Pies/Apple Pie Recipes/
# 2                        /Side Dish/Applesauce Recipes/
# 3     /Desserts/Crisps and Crumbles Recipes/Apple Cr...
# 4                     /Desserts/Pies/Apple Pie Recipes/
# ...                                                 ...
# 1085       /Desserts/Cookies/Fruit Cookie Recipes/Date/
# 1086   /Desserts/Fruit Desserts/Banana Dessert Recipes/
# 1087                  /Side Dish/Sauces and Condiments/
# 1088     /Breakfast and Brunch/Breakfast Bread Recipes/
# 1089  /Appetizers and Snacks/Snacks/Granola Bar Reci...
#
#                                               nutrition  \
# 0     Total Fat 18g 23%, Saturated Fat 7g 34%, Chole...
# 1     Total Fat 19g 24%, Saturated Fat 9g 46%, Chole...
# 2     Total Fat 0g 0%, Sodium 3mg 0%, Total Carbohyd...
# 3     Total Fat 8g 11%, Saturated Fat 5g 25%, Choles...
# 4     Total Fat 0g 0%, Sodium 61mg 3%, Total Carbohy...
# ...                                                 ...
# 1085  Total Fat 5g 6%, Saturated Fat 2g 12%, Cholest...
# 1086  Total Fat 33g 43%, Saturated Fat 4g 21%, Chole...
# 1087  Total Fat 1g 1%, Saturated Fat 0g 1%, Sodium 2...
# 1088  Total Fat 10g 13%, Saturated Fat 3g 16%, Chole...
# 1089  Total Fat 22g 28%, Saturated Fat 7g 36%, Sodiu...
#
#                                                  timing  \
# 0                 Servings: 8, Yield: 6 to 8 - servings
# 1     Prep Time: 30 mins, Cook Time: 1 hrs, Total Ti...
# 2     Prep Time: 10 mins, Cook Time: 15 mins, Total ...
# 3     Prep Time: 30 mins, Cook Time: 45 mins, Total ...
# 4     Prep Time: 20 mins, Cook Time: 20 mins, Additi...
# ...                                                 ...
# 1085  Prep Time: 15 mins, Cook Time: 10 mins, Additi...
# 1086             Servings: 14, Yield: 1 - 13x9 inch pan
# 1087  Prep Time: 10 mins, Cook Time: 20 mins, Total ...
# 1088  Prep Time: 15 mins, Cook Time: 50 mins, Additi...
# 1089  Prep Time: 15 mins, Additional Time: 2 hrs 45 ...
#
#                                                 img_src
# 0     https://www.allrecipes.com/thmb/Tf1wH73bfH6Oql...
# 1     https://www.allrecipes.com/thmb/1I95oiTGz6aEpu...
# 2     https://www.allrecipes.com/thmb/VY5d0tZHB8xz6y...
# 3     https://www.allrecipes.com/thmb/uAzhPOh86PfR-N...
# 4     https://www.allrecipes.com/thmb/c0bbYaS1V_mTt_...
# ...                                                 ...
# 1085  https://www.allrecipes.com/thmb/LXm_15zLymhZ7c...
# 1086  https://www.allrecipes.com/thmb/tI7g5xY5-qPV5v...
# 1087  https://www.allrecipes.com/thmb/80wUYzFvbycfxx...
# 1088  https://www.allrecipes.com/thmb/bYsnompJZ6UAF9...
# 1089  https://www.allrecipes.com/thmb/IOoj42MMo8YNKW...
#
# [1090 rows x 15 columns]

# %%
df["recipe_name"].duplicated().value_counts() #Checking for any duplicate entries
# Out:
# False    961
# True     129
# Name: recipe_name, dtype: int64

# %%
#A basic description of the dataset, it is observed that serving size is as high as 961, we may explore on it further
df.describe()
# Out:
#         Unnamed: 0     servings       rating
# count  1090.000000  1090.000000  1090.000000
# mean    544.500000    13.755046     4.533853
# std     314.800201    19.886076     0.349814
# min       0.000000     1.000000     2.000000
# 25%     272.250000     6.000000     4.400000
# 50%     544.500000     8.000000     4.600000
# 75%     816.750000    12.000000     4.700000
# max    1089.000000   240.000000     5.000000

# %%
df.drop_duplicates(subset="recipe_name",inplace=True)

# %%
#Checking the number of null values in each column
df.isnull().sum()
# Out:
# Unnamed: 0        0
# recipe_name       0
# prep_time        47
# cook_time       289
# total_time       41
# servings          0
# yield           167
# ingredients       0
# directions        0
# rating            0
# url               0
# cuisine_path      0
# nutrition         0
# timing            0
# img_src           0
# dtype: int64

# %%
#Dropping the yield column since its similar to the servings
#Dropping the cook_time and prep_time
df.drop(['prep_time','cook_time','yield'], axis=1, inplace=True)

# %%
df2["Name"].duplicated().value_counts() #Checking for duplicate entries
# Out:
# False    59
# Name: Name, dtype: int64

# %%
#Creating new dataframes to store the total_time taken for the recipe for visualization
df1_recipes=pd.DataFrame()
df2_recipes=pd.DataFrame()

# %%
#Creating a function to convert the total_time to mins as they are in different formats(On both datasets)
def convert(x):
    if x is None:
        return np.nan
    else:
        x=str(x)
        lst=x.split(" ")
        time=0
        if "days" in lst:
            time+=int(lst[lst.index("days") - 1])*60*24
        if "hrs" in lst:
            time+=int(lst[lst.index("hrs") - 1])*60
        if "mins" in lst:
            time+=int(lst[lst.index("mins") - 1])
        return time

# %%
df1_recipes["total_time"]=df["total_time"].apply(convert)

# %%
df2_recipes["Total Time"]=df2["Total Time"].apply(convert)

# %%
df1_recipes
# Out:
#       total_time
# 0              0
# 1             90
# 2             25
# 3             75
# 4            160
# ...          ...
# 1085          30
# 1086           0
# 1087          30
# 1088          95
# 1089         180
#
# [961 rows x 1 columns]

# %%
df2_recipes.head(10)
# Out:
#    Total Time
# 0          60
# 1          40
# 2          65
# 3          20
# 4          35
# 5          30
# 6          45
# 7         170
# 8          45
# 9          45

# %%
#Cuisine is extracted from the cuisne path column to extract the exact dataset
new_cuisine=[]
for index,row in df.iterrows():
    if (row['cuisine_path'].partition('/')[2].partition('/')[0]) !="Cuisine":
         val= row['cuisine_path'].partition('/')[2].partition('/')[0]
         new_cuisine.append(val)
    else:
        val2=row['cuisine_path'].partition('/')[2].partition('/')[2].partition('/')[0]
        new_cuisine.append(val2)
df["Cuisines"]=new_cuisine

# %%
#Outlier analysis to check the values that have a higher serving_size,Since its of side-dishes no further analysis is required
df["Cuisines"][df["servings"]>70].value_counts()
# Out:
# Side Dish         16
# Desserts           4
# Drinks Recipes     1
# Name: Cuisines, dtype: int64

# %%
#Doing a basic visualization to understand themost popular recipe category
plt.title('Most Popular Recipe Category', y=1.03, x=0.483, fontsize=15)
plt.suptitle('Data from AllRecipes', y=0.90)

ax = (
    df["Cuisines"]
    .value_counts()
    .sort_values(ascending=True)
    .plot(kind='barh', figsize=(20, 13),colormap="summer")
)
ax.bar_label(ax.containers[0])  # bar annotation

plt.xlabel('Amount of Category Occurrences', labelpad=10, fontsize=15)
plt.ylabel('Type of Cuisine', labelpad=10, fontsize=15)
plt.show()

# %%
rating=df.groupby(["Cuisines"])['rating'].mean()
fontsize=20
plt.rcParams["figure.figsize"] = (20,10)
rating.plot(kind="bar",stacked=True)
plt.title('Average Rating by Cuisine', y=1.04, x=0.483, fontsize=10)
plt.xticks(rotation=90, ha='center')
plt.xlabel('Type of Cuisine')
plt.ylabel('Average rating')
plt.show()

# %%
#The below program is created to extract the nutritional types and their corrresponding values(A seprste mg/g col will be created for the same nutritional type if it exisits)
amount = 0
amountString = ""
name = ""
nutrition = pd.DataFrame()
nutrition["recipe_name"] = df["recipe_name"]
nutrition["rating"] = df["rating"]
for i, recipe in df.iterrows():
    stuff = recipe["nutrition"].split(", ")
    for nutrient in stuff:
        words = nutrient.split(" ")
        name = ""
        for word in words:
            if word[-1] == 'g':
                if word[-2] == 'm':
                    amount = int(word[:-2])
                    name += "(mg)"
                else: 
                    amount = int(word[:-1])
                    name += "(g)"
                amountString = word
            elif word[-1] != '%':
                name += word + " "
        #print(name)
        #print(amountString)
        name = name.strip()
        if name in nutrition.columns:
            nutrition[name][i] = amount
        else:
            nutrition[name] = 0
            nutrition[name][i] = amount

# %%
nutrition
# Out:
#                             recipe_name  rating  Total Fat (g)  \
# 0              Apple-Cranberry Crostada     4.4             18
# 1             Apple Pie by Grandma Ople     4.8             19
# 2           Sarah's Homemade Applesauce     4.8              0
# 3                           Apple Crisp     4.7              8
# 4                     Apple Pie Filling     4.7              0
# ...                                 ...     ...            ...
# 1085                     Date-Nut Balls     3.8              5
# 1086                       Jamaica Cake     4.6             33
# 1087                     Best Hot Sauce     4.9              1
# 1088               Moist Date Nut Bread     4.5             10
# 1089  Chef John's Chocolate Energy Bars     4.8             22
#
#       Saturated Fat (g)  Cholesterol (mg)  Sodium (mg)  \
# 0                     7                19          128
# 1                     9                31          124
# 2                     0                 0            3
# 3                     5                20           98
# 4                     0                 0           61
# ...                 ...               ...          ...
# 1085                  2                 9           33
# 1086                  4                40          272
# 1087                  0                 0           29
# 1088                  3                26          365
# 1089                  7                 0          230
#
#       Total Carbohydrate (g)  Dietary Fiber (g)  Total Sugars (g)  \
# 0                         60                  5                40
# 1                         52                  3                 0
# 2                         32                  4                27
# 3                         61                  3                44
# 4                         33                  1                28
# ...                      ...                ...               ...
# 1085                       8                  1                 7
# 1086                      61                  3                37
# 1087                       1                  0                 0
# 1088                      47                  4                30
# 1089                      36                  7                21
#
#       Protein (g)  Vitamin C (mg)  Calcium (mg)  Iron (mg)  Potassium (mg)
# 0               4               8            35          1             245
# 1               2               5            23          1             156
# 2               0               6            13          0             150
# 3               2               4            36          1             162
# 4               0               3             7          0              63
# ...           ...             ...           ...        ...             ...
# 1085            0               1             4          1              32
# 1086            6               5            25          2             201
# 1087            0              11             2          0              21
# 1088            4               0            51          2             312
# 1089            8               0            59          3             515
#
# [961 rows x 14 columns]

# %%
#Making 4 quartilies to understand the distribution of the nutritional intormation(Macro-nutrients) based on ratings
q = nutrition.quantile([0.00, 0.25, 0.50, 0.75, 1.00])

#print(q)

df_nutri = nutrition.copy()
df_nutri.drop(['recipe_name', 'Sodium (mg)','Potassium (mg)','Saturated Fat (g)','Total Carbohydrate (g)','Cholesterol (mg)', 'Vitamin C (mg)', 'Calcium (mg)', 'Iron (mg)'], axis = 1, inplace=True)
#print(df)
col = 'rating'
qcol = 'rating'

q1 = df_nutri[((df_nutri[col]>=q[qcol][0.00]) & (df_nutri[col]<q[qcol][0.25]))]
q1.drop(['rating'], axis = 1, inplace=True)
q2 = df_nutri[((df_nutri[col]>=q[qcol][0.25]) & (df_nutri[col]<q[qcol][0.50]))]
q2.drop(['rating'], axis = 1, inplace=True)
q3 = df_nutri[((df_nutri[col]>=q[qcol][0.50]) & (df_nutri[col]<q[qcol][0.75]))]
q3.drop(['rating'], axis = 1, inplace=True)
q4 = df_nutri[((df_nutri[col]>=q[qcol][0.75]) & (df_nutri[col]<=q[qcol][1.00]))]
q4.drop(['rating'], axis = 1, inplace=True)

# %%
#Pie-chart is plotted for the same visualization
plt.title("First Quartile of Ratings")
plt.pie(q1.sum(), labels=q1.columns, radius = 1,autopct='%1.1f%%')
plt.figure()
plt.title("Second Quartile of Ratings")
plt.pie(q2.sum(), labels=q2.columns, radius = 1,autopct='%1.1f%%')
plt.figure()
plt.title("Third Quartile of Ratings")
plt.pie(q3.sum(), labels=q3.columns, radius = 1,autopct='%1.1f%%')
plt.figure()
plt.title("Fourth Quartile of Ratings")
plt.pie(q4.sum(), labels=q4.columns, radius = 1,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x23b70922d90>,
#   <matplotlib.patches.Wedge at 0x23b7092f790>,
#   <matplotlib.patches.Wedge at 0x23b7092feb0>,
#   <matplotlib.patches.Wedge at 0x23b70939610>],
#  [Text(0.6498608501051457, 0.8875138734130399, 'Total Fat (g)'),
#   Text(-0.5193643169269552, 0.9696704111722692, 'Dietary Fiber (g)'),
#   Text(-0.888389817505791, -0.6486628802020564, 'Total Sugars (g)'),
#   Text(0.9689688407739132, -0.5206720518803166, 'Protein (g)')],
#  [Text(0.3544695546028067, 0.4840984764071126, '29.9%'),
#   Text(-0.2832896274147028, 0.5289111333666922, '5.9%'),
#   Text(-0.48457626409406773, -0.3538161164738489, '48.5%'),
#   Text(0.5285284586039526, -0.2840029373892636, '15.7%')])

# %%
#Creating a program to handle the unicode values and convert them to fractions
import unicodedata
unicodedata.numeric(u'¼')
unicodedata.name(u'¼')

agre = pd.DataFrame(columns=['quantity', 'Name'])
potato = 0

#convert vulgar fractions
for ix, row in df.iterrows():
    str = row["ingredients"]
    chunks = str.split(" ")
    #print(chunks)
    chunkSum = 0
    chunkString = ""
    hasNum = False
    for chunk in chunks:
        if len(chunk) > 0:
            if unicodedata.name(chunk[0]).startswith('VULGAR FRACTION'):
                normalized = unicodedata.normalize('NFKC', chunk)
                numerator, _slash, denominator = normalized.partition('⁄')
                val = float(numerator)/float(denominator)
                chunkSum += val
                #print(chunk)
                hasNum = True
            elif chunk.isdigit():
                chunkSum += float(chunk)
                hasNum = True
            else:
                chunkString += " " + chunk
        chunkString = chunkString.strip()
    if hasNum:
        agre.loc[len(agre.index)] = [chunkSum,chunkString]

# %%
agre
# Out:
#      quantity                                               Name
# 0       11.00  tablespoons butter, pounds Granny Smith apples...
# 1       13.75  small Granny Smith apples, or as needed, cup u...
# 2        5.50  apples - peeled, cored and chopped, cup water,...
# 3       17.50  cups all-purpose apples, peeled, cored and sli...
# 4       39.75  cups thinly sliced apples, tablespoons lemon j...
# ..        ...                                                ...
# 955     21.00  tablespoons butter, cup pitted chopped dates, ...
# 956     17.00  cups white sugar, cups vegetable oil, cups cho...
# 957     20.25  fresh hot chile peppers, stems removed, onion,...
# 958     10.75  cups chopped dates, cup butter, cup boiling wa...
# 959     12.25  cups pitted Medjool dates, roughly chopped, cu...
#
# [960 rows x 2 columns]

# %%
#Creating a code to seperate the units,quantities and the ingredients into seperate columns
SEPARATOR_RE = re.compile(r'^([\d\s*[\d\.,/]*)\s*(.+)')


def normalize(st):
    return re.sub(r'\s+', ' ', SEPARATOR_RE.sub('\g<1> \g<2>', st)).strip()


def escape_re_string(text):
    text = text.replace('.', '\.')
    return re.sub(r'\s+', ' ', text)

unit = {"cup": ["cups", "cup", "c.", "c"], "fluid_ounce": ["fl. oz.", "fl oz", "fluid ounce", "fluid ounces"],
         "gallon": ["gal", "gal.", "gallon", "gallons"], "ounce": ["oz", "oz.", "ounce", "ounces"],
         "pint": ["pt", "pt.", "pint", "pints"], "pound": ["lb", "lb.", "pound", "pounds"],
         "quart": ["qt", "qt.", "qts", "qts.", "quart", "quarts"],
         "tablespoon": ["tbsp.", "tbsp", "T", "T.", "tablespoon", "tablespoons", "tbs.", "tbs"],
         "teaspoon": ["tsp.", "tsp", "t", "t.", "teaspoon", "teaspoons"],
         "gram": ["g", "g.", "gr", "gr.", "gram", "grams"], "kilogram": ["kg", "kg.", "kilogram", "kilograms"],
         "liter": ["l", "l.", "liter", "liters"], "milligram": ["mg", "mg.", "milligram", "milligrams"],
         "milliliter": ["ml", "ml.", "milliliter", "milliliters"], "pinch": ["pinch", "pinches"],
         "dash": ["dash", "dashes"], "touch": ["touch", "touches"], "handful": ["handful", "handfuls"],
         "stick": ["stick", "sticks"], "clove": ["cloves", "clove"], "can": ["cans", "can"], "large": ["large"],
         "small": ["small"], "scoop": ["scoop", "scoops"], "filets": ["filet", "filets"], "sprig": ["sprigs", "sprig"],
         "Skinless":["Skinless","skinless"]}
quantity = ['17', '18', '13', '19', '14', '16', '15', '17', '12',
           '11', '80', '30', '90', '20', '7', '50', '60', '40', '3', '8',
           '4', '0', '5', '9', '10', '1', '6', '2', 'an','1/4','1/2']

# %%
a = list(chain.from_iterable(unit.values()))
a.sort(key=lambda x: len(x), reverse=True)
a = map(escape_re_string, a)
prepositions = ["of"]

# %%
#Parsing through the quantities that need to be extracted
PARSER_RE = re.compile(
    r'(?P<quantity>(?:[\d\.,][\d\.,\s/]*)?\s*(?:(?:%s)\s*)*)?(\s*(?P<unit>%s)\s+)?(\s*(?:%s)\s+)?(\s*(?P<Name>.+))?' % ('|'.join(quantity), '|'.join(a), '|'.join(prepositions)))

# %%
df1 = agre["Name"].str.extract(PARSER_RE, expand=False).drop(columns=[1,3,4])

# %%
df1
# Out:
#     quantity         unit                                               Name
# 0             tablespoons  butter, pounds Granny Smith apples (or other f...
# 1                   small  Granny Smith apples, or as needed, cup unsalte...
# 2                     NaN  apples - peeled, cored and chopped, cup water,...
# 3                    cups  all-purpose apples, peeled, cored and sliced, ...
# 4                    cups  thinly sliced apples, tablespoons lemon juice,...
# ..       ...          ...                                                ...
# 955           tablespoons  butter, cup pitted chopped dates, cup white su...
# 956                  cups  white sugar, cups vegetable oil, cups chopped ...
# 957                   NaN  fresh hot chile peppers, stems removed, onion,...
# 958                  cups  chopped dates, cup butter, cup boiling water, ...
# 959                  cups  pitted Medjool dates, roughly chopped, cups ra...
#
# [960 rows x 3 columns]

# %%
df1["unit"].value_counts().head(20)
# Out:
# cup            235
# cups           227
# tablespoons     54
# pounds          37
# large           27
# ounces          16
# tablespoon      12
# pound           12
# teaspoon        11
# small            7
# quart            5
# fluid ounce      2
# teaspoons        2
# quarts           2
# stick            1
# sprigs           1
# gallons          1
# cloves           1
# clove            1
# pint             1
# Name: unit, dtype: int64

# %%
df1
# Out:
#     quantity         unit                                               Name
# 0             tablespoons  butter, pounds Granny Smith apples (or other f...
# 1                   small  Granny Smith apples, or as needed, cup unsalte...
# 2                     NaN  apples - peeled, cored and chopped, cup water,...
# 3                    cups  all-purpose apples, peeled, cored and sliced, ...
# 4                    cups  thinly sliced apples, tablespoons lemon juice,...
# ..       ...          ...                                                ...
# 955           tablespoons  butter, cup pitted chopped dates, cup white su...
# 956                  cups  white sugar, cups vegetable oil, cups chopped ...
# 957                   NaN  fresh hot chile peppers, stems removed, onion,...
# 958                  cups  chopped dates, cup butter, cup boiling water, ...
# 959                  cups  pitted Medjool dates, roughly chopped, cups ra...
#
# [960 rows x 3 columns]

# %%
#load the existing small model from spacy, to get the meaningful ingredients list out of the entire ingredients description,
def cleaning(df,col_value,col_value_new):
            base_model = spacy.load('en_core_web_sm')
            
            measurements = re.compile(r'(bowl|bulb|cube|clove|cup|drop|ounce|oz|pinch|pound|teaspoon|tablespoon|large|small)s?')
            extracted = []
            
            for ix, row in df.iterrows():
                print('\r', "Extracting ingredient for row", ix, end='')
                tokens = base_model(row[col_value])
                extract = ''
                for token in tokens:
                    if (token.dep_ in ['nsubj', 'ROOT']) and (token.pos_ in ['NOUN', 'PROPN']) and (not measurements.match(token.text)):
                    #explore children
                        for child in token.children:
                            if (not measurements.match(child.text)) and (child.dep_ in ['amod', 'compound']):
                                extract += child.text + ' '
                        extract += token.text + ' '
                extracted.append(extract)
                
            #convert to dataframe to view 
            df[col_value_new] = extracted
            
            nan_value = float("NaN")
            
            df.replace("", nan_value, inplace=True)
            
            df.dropna(subset = [col_value_new], inplace=True)

# %%
cleaning(df1,"Name","name")
# Out:
#  Extracting ingredient for row 959

# %%
base_model = spacy.load('en_core_web_sm')

# %%
#Stemming/lemmatization to get to the root words
df1["name"]=df1["name"].apply(lambda row: " ".join([w.lemma_ for w in base_model(row)]))

# %%
df1.drop(columns="Name",inplace=True)

# %%
count_df1=pd.DataFrame(df1.name.value_counts().rename_axis('Name').reset_index(name='count'))
count_df1.head(15)
# Out:
#                 Name  count
# 0        white sugar     52
# 1      purpose flour     49
# 2             butter     20
# 3                egg     14
# 4      cooking spray      9
# 5              water      9
# 6        brown sugar      8
# 7            package      8
# 8   fresh strawberry      7
# 9             banana      7
# 10              milk      7
# 11         olive oil      7
# 12         nectarine      6
# 13      cream cheese      6
# 14    unsalte butter      6

# %%
df1
# Out:
#      quantity         unit                                   name
# 0         NaN  tablespoons  Smith apple Macintosh apple ice cream
# 1         NaN        small                            Smith apple
# 2         NaN          NaN                 peel cored white sugar
# 3         NaN         cups                          purpose apple
# 4         NaN         cups                            slice apple
# ..        ...          ...                                    ...
# 955       NaN  tablespoons                          pit chop date
# 956       NaN         cups                            white sugar
# 957       NaN          NaN                 fresh hot chile pepper
# 958       NaN         cups                chop date purpose flour
# 959       NaN         cups                       pit Medjool date
#
# [872 rows x 3 columns]

# %%
#A view of the second data
df2
# Out:
#     Row                                               Name Prep Time  \
# 0     0                  Indian Chicken Curry (Murgh Kari)   20 mins
# 1     1                                   Chicken Stir-Fry   20 mins
# 2     2                                          Jambalaya   20 mins
# 3     3                                      Chicken Katsu   10 mins
# 4     4                       Simple Baked Chicken Breasts   10 mins
# 5     5                                    Chicken Marsala   10 mins
# 6     6                      Baked Garlic Parmesan Chicken   15 mins
# 7     7                               Asian Orange Chicken   20 mins
# 8     8                                Chicken Quesadillas   20 mins
# 9     9                                Chicken Cordon Bleu   10 mins
# 10   10                  Slow Cooker Chicken and Dumplings   10 mins
# 11   11                                        Easy Paella   30 mins
# 12   12                    Air Fryer Frozen Chicken Strips    5 mins
# 13   13                                            Banh Mi   30 mins
# 14   14                               Easy Italian Chicken    5 mins
# 15   15                         Yummy Honey Chicken Kabobs   15 mins
# 16   16                           Chicken Noodle Casserole   30 mins
# 17   17         Sarah's Easy Shredded Chicken Taco Filling   15 mins
# 18   18                              Baked Chicken Nuggets   20 mins
# 19   19                           Pesto Pasta with Chicken   10 mins
# 20   20                         Easy Indian Butter Chicken   15 mins
# 21   21                                  Blackened Chicken   10 mins
# 22   22                                Cajun Chicken Pasta   20 mins
# 23   23                           Chef John's Chicken Kiev   30 mins
# 24   24                                   Kung Pao Chicken   30 mins
# 25   25                   Tender Pan-Fried Chicken Breasts   20 mins
# 26   26                       Poppy Seed Chicken Casserole   20 mins
# 27   27                               Honey Glazed Chicken   10 mins
# 28   28                               Indian Chicken Curry   20 mins
# 29   29                             Boneless Buffalo Wings   10 mins
# 30   30                           Famous Chicken Française   20 mins
# 31   31               Oven Roasted Stuffed Chicken Breasts   30 mins
# 32   32                            Baked Chicken Schnitzel   20 mins
# 33   33              Cheesy Chicken and Broccoli Casserole   15 mins
# 34   34                           Easy White Chicken Chili   20 mins
# 35   35                       Crispy Panko Chicken Breasts   10 mins
# 36   36                           Grilled Chicken Marinade   10 mins
# 37   37                                 Chicken Enchiladas   25 mins
# 38   38                       Slow Cooker Barbeque Chicken   10 mins
# 39   39             Three-Ingredient Baked Chicken Breasts   10 mins
# 40   40                                  Mulligatawny Soup   20 mins
# 41   41                              Grilled Asian Chicken   15 mins
# 42   42               Chicken Souvlaki with Tzatziki Sauce   15 mins
# 43   43             Slow Cooker Buffalo Chicken Sandwiches   10 mins
# 44   44                              Lemon Chicken Piccata   20 mins
# 45   45                 Zesty Slow Cooker Chicken Barbecue   10 mins
# 46   46                              Quick Chicken Piccata   10 mins
# 47   47                           Parmesan Crusted Chicken   10 mins
# 48   48                      Air Fryer Chicken Cordon Bleu   15 mins
# 49   49                               Chicken Tikka Masala   30 mins
# 50   50                        Baked Honey Mustard Chicken   15 mins
# 51   51  Air Fryer Chicken Katsu with Homemade Katsu Sauce   20 mins
# 52   52                                      Salsa Chicken    5 mins
# 53   53                       Easy Chicken Fajita Marinade   15 mins
# 54   54                      Slow Cooker Chicken Taco Soup   15 mins
# 55   55             Curry Stand Chicken Tikka Masala Sauce   15 mins
# 56   56                                             Kabobs   30 mins
# 57   57           Chef John's Homemade Chicken Noodle Soup   20 mins
# 58   58                      Broccoli and Chicken Stir-Fry   15 mins
#
#        Cook Time     Total Time  Servings                    Yield  \
# 0        40 mins          1 hrs         6               6 servings
# 1        20 mins        40 mins         6                      NaN
# 2        45 mins   1 hrs 5 mins         6               6 servings
# 3        10 mins        20 mins         4               4 servings
# 4        25 mins        35 mins         4                      NaN
# 5        20 mins        30 mins         4               4 servings
# 6        30 mins        45 mins         6               6 servings
# 7        20 mins  2 hrs 50 mins         4                      NaN
# 8        25 mins        45 mins        10                      NaN
# 9        35 mins        45 mins         4               4 servings
# 10         5 hrs  5 hrs 10 mins         8                      NaN
# 11       30 mins          1 hrs         8                      NaN
# 12       11 mins        16 mins         8                      NaN
# 13       20 mins        50 mins         2       1 12-inch sandwich
# 14         1 hrs   2 hrs 5 mins         6                      NaN
# 15       15 mins  2 hrs 30 mins        12                      NaN
# 16       55 mins  1 hrs 25 mins         6      1 2-quart casserole
# 17       15 mins        40 mins         3                      NaN
# 18       20 mins        40 mins         6                      NaN
# 19       20 mins        30 mins         8                      NaN
# 20       45 mins          1 hrs         6                      NaN
# 21       10 mins        20 mins         2  2 chicken breast halves
# 22       20 mins        40 mins         2                      NaN
# 23       20 mins  1 hrs 35 mins         4                      NaN
# 24       30 mins  1 hrs 30 mins         4                      NaN
# 25       25 mins        55 mins         8        8 chicken breasts
# 26       50 mins  1 hrs 10 mins         6       1 9-inch casserole
# 27       10 mins        20 mins         4                      NaN
# 28       25 mins        45 mins         4                      NaN
# 29       20 mins        50 mins         3                      NaN
# 30       15 mins        35 mins         6                      NaN
# 31       45 mins  1 hrs 15 mins         6                      NaN
# 32       10 mins        30 mins         6                      NaN
# 33       35 mins        50 mins         8    1 9x13-inch casserole
# 34       35 mins        55 mins         4                      NaN
# 35        5 mins        15 mins         4                      NaN
# 36       10 mins  4 hrs 20 mins         5                      NaN
# 37       35 mins  1 hrs 10 mins         8             8 enchiladas
# 38         4 hrs  4 hrs 10 mins         4                      NaN
# 39       30 mins        40 mins         4                      NaN
# 40         1 hrs  1 hrs 20 mins         6                      NaN
# 41       15 mins        50 mins         4                      NaN
# 42       15 mins  2 hrs 30 mins         6                      NaN
# 43         6 hrs  6 hrs 10 mins         6             6 sandwiches
# 44       30 mins        50 mins         4               4 servings
# 45         3 hrs  3 hrs 10 mins         6                      NaN
# 46       15 mins        25 mins         4                      NaN
# 47       20 mins        30 mins         4                      NaN
# 48       20 mins        40 mins         2                      NaN
# 49       50 mins  2 hrs 20 mins         4                      NaN
# 50       40 mins   1 hrs 5 mins         6                      NaN
# 51       20 mins        40 mins         4                      NaN
# 52       30 mins        35 mins         4                      NaN
# 53       20 mins  4 hrs 35 mins        10                      NaN
# 54         7 hrs  7 hrs 15 mins         8                      NaN
# 55  1 hrs 5 mins  1 hrs 20 mins         6                      NaN
# 56       10 mins  4 hrs 40 mins        10                      NaN
# 57       20 mins        40 mins         8                      NaN
# 58       20 mins        35 mins         3                      NaN
#
#                                           Ingredients  \
# 0   [{'quantity': '2', 'unit': 'pounds', 'name': '...
# 1   [{'quantity': '4', 'unit': 'cups', 'name': 'wa...
# 2   [{'quantity': '2', 'unit': 'tablespoons', 'nam...
# 3   [{'quantity': '4', 'unit': '', 'name': 'skinle...
# 4   [{'quantity': '4', 'unit': '(5 ounce)', 'name'...
# 5   [{'quantity': '¼', 'unit': 'cup', 'name': 'all...
# 6   [{'quantity': '2', 'unit': 'tablespoons', 'nam...
# 7   [{'quantity': '1 ½', 'unit': 'cups', 'name': '...
# 8   [{'quantity': '1', 'unit': 'pound', 'name': 's...
# 9   [{'quantity': '', 'unit': '', 'name': 'nonstic...
# 10  [{'quantity': '4', 'unit': '', 'name': 'skinle...
# 11  [{'quantity': '2', 'unit': 'tablespoons', 'nam...
# 12  [{'quantity': '25', 'unit': 'ounces', 'name': ...
# 13  [{'quantity': '½', 'unit': 'cup', 'name': 'ric...
# 14  [{'quantity': '1', 'unit': '(16 ounce) bottle'...
# 15  [{'quantity': '⅓', 'unit': 'cup', 'name': 'hon...
# 16  [{'quantity': '4', 'unit': '', 'name': 'skinle...
# 17  [{'quantity': '1', 'unit': 'pound', 'name': 's...
# 18  [{'quantity': '3', 'unit': '', 'name': 'skinle...
# 19  [{'quantity': '1', 'unit': '(16 ounce) package...
# 20  [{'quantity': '1', 'unit': 'cup', 'name': 'but...
# 21  [{'quantity': '½', 'unit': 'teaspoon', 'name':...
# 22  [{'quantity': '4', 'unit': 'ounces', 'name': '...
# 23  [{'quantity': '2', 'unit': 'cloves', 'name': '...
# 24  [{'quantity': '2', 'unit': 'tablespoons', 'nam...
# 25  [{'quantity': '2', 'unit': 'cups', 'name': 'fl...
# 26  [{'quantity': '4', 'unit': '', 'name': 'skinle...
# 27  [{'quantity': '¼', 'unit': 'cup', 'name': 'hon...
# 28  [{'quantity': '3', 'unit': 'tablespoons', 'nam...
# 29  [{'quantity': '', 'unit': '', 'name': 'oil for...
# 30  [{'quantity': '1', 'unit': 'large', 'name': 'e...
# 31  [{'quantity': '1', 'unit': 'cup', 'name': 'par...
# 32  [{'quantity': '1', 'unit': 'tablespoon', 'name...
# 33  [{'quantity': '1', 'unit': 'teaspoon', 'name':...
# 34  [{'quantity': '1', 'unit': 'tablespoon', 'name...
# 35  [{'quantity': '1', 'unit': 'pound', 'name': 'b...
# 36  [{'quantity': '¼', 'unit': 'cup', 'name': 'red...
# 37  [{'quantity': '1', 'unit': 'tablespoon', 'name...
# 38  [{'quantity': '4', 'unit': '', 'name': 'skinle...
# 39  [{'quantity': '¼', 'unit': 'cup', 'name': 'but...
# 40  [{'quantity': '½', 'unit': 'cup', 'name': 'cho...
# 41  [{'quantity': '¼', 'unit': 'cup', 'name': 'soy...
# 42  [{'quantity': '¼', 'unit': 'cup', 'name': 'oli...
# 43  [{'quantity': '4', 'unit': '', 'name': 'skinle...
# 44  [{'quantity': '3', 'unit': 'large', 'name': 's...
# 45  [{'quantity': '6', 'unit': '', 'name': 'frozen...
# 46  [{'quantity': '4', 'unit': '', 'name': 'skinle...
# 47  [{'quantity': '½', 'unit': 'cup', 'name': "Hel...
# 48  [{'quantity': '2', 'unit': '', 'name': 'bonele...
# 49  [{'quantity': '1', 'unit': 'cup', 'name': 'yog...
# 50  [{'quantity': '', 'unit': '', 'name': 'cooking...
# 51  [{'quantity': '½', 'unit': 'cup', 'name': 'ket...
# 52  [{'quantity': '4', 'unit': '', 'name': 'skinle...
# 53  [{'quantity': '½', 'unit': 'cup', 'name': 'veg...
# 54  [{'quantity': '2', 'unit': '(10 ounce) cans', ...
# 55  [{'quantity': '2', 'unit': 'tablespoons', 'nam...
# 56  [{'quantity': '½', 'unit': 'cup', 'name': 'ter...
# 57  [{'quantity': '1', 'unit': 'tablespoon', 'name...
# 58  [{'quantity': '⅔', 'unit': 'cup', 'name': 'soy...
#
#                                            Directions  \
# 0   ['Sprinkle the chicken breasts with 2 teaspoon...
# 1   ['Bring water and rice to a boil in a saucepan...
# 2   ['Heat 1 tablespoon of peanut oil in a large h...
# 3   ['Season the chicken breasts on both sides wit...
# 4   ['Preheat the oven to 400 degrees F (200 degre...
# 5   ['In a shallow dish or bowl, mix together the ...
# 6   ['Preheat oven to 350 degrees F (175 degrees C...
# 7   ['Combine water, rice vinegar, lemon juice, so...
# 8   ['Preheat the broiler. Lightly grease a baking...
# 9   ['Preheat oven to 350 degrees F (175 degrees C...
# 10  ['Place chicken, condensed soup, onion, and bu...
# 11  ['Mix olive oil, paprika, oregano, salt, and p...
# 12  ['Set the air fryer temperature to 380 degrees...
# 13  ['Combine rice vinegar, sugar, and water in a ...
# 14  ['Pour salad dressing into a large resealable ...
# 15  ['Whisk together honey, soy sauce, oil, and bl...
# 16  ['Preheat the oven to 350 degrees F (175 degre...
# 17  ['Place chicken breasts in a saucepan and cove...
# 18  ['Preheat the oven to 400 degrees F (200 degre...
# 19  ['Bring a large pot of lightly salted water to...
# 20  ['Preheat the oven to 375 degrees F (190 degre...
# 21  ['Preheat the oven to 350 degrees F (175 degre...
# 22  ['Bring a large pot of lightly salted water to...
# 23  ['Grind garlic and pinch of salt together in a...
# 24  ['Combine water and cornstarch in cup. Set asi...
# 25  ['Stir together flour, salt, pepper, tarragon,...
# 26  ['Place chicken breasts into a large pot; cove...
# 27  ['Whisk honey, soy sauce, and red pepper flake...
# 28  ['Heat olive oil in a skillet over medium heat...
# 29  ['Heat oil in a deep-fryer or large saucepan t...
# 30  ['Mix together egg and 1/3 of the lemon juice ...
# 31  ['Preheat the oven to 350 degrees F (175 degre...
# 32  ['Preheat the oven to 425 degrees F (220 degre...
# 33  ['Preheat the oven to 350 degrees F (175 degre...
# 34  ['Heat olive oil in a Dutch oven over medium h...
# 35  ['Pound chicken breasts, one at a time, in a r...
# 36  ['Whisk vinegar, soy sauce, olive oil, parsley...
# 37  ['Preheat the oven to 350 degrees F (175 degre...
# 38  ['Place chicken breast halves in a slow cooker...
# 39  ['Preheat the oven to 350 degrees F (175 degre...
# 40  ['Melt butter in a large soup pot over medium ...
# 41  ['Combine soy sauce, honey, sesame oil, garlic...
# 42  ['Prepare kabobs: Combine olive oil, garlic, l...
# 43  ['Place chicken breasts into the slow cooker; ...
# 44  ['Preheat oven to 200 degrees F (95 degrees C)...
# 45  ['Place chicken in the slow cooker. Mix barbec...
# 46  ['Place chicken breasts between 2 sheets of he...
# 47  ['Preheat the oven to 425 degrees F (220 degre...
# 48  ['Place a chicken breast on a flat work surfac...
# 49  ['Combine yogurt, lemon juice, 2 teaspoons cum...
# 50  ['Preheat the oven to 350 degrees F (175 degre...
# 51  ['Prepare sauce: Whisk ketchup, soy sauce, bro...
# 52  ['Preheat the oven to 375 degrees F (190 degre...
# 53  ['Whisk vegetable oil, chili powder, lime juic...
# 54  ['Place diced tomatoes, chili beans, black bea...
# 55  ['Heat ghee in a large skillet over medium hea...
# 56  ['Mix teriyaki sauce, honey, garlic powder, an...
# 57  ['Melt butter in a large soup pot over medium ...
# 58  ['Stir soy sauce, brown sugar, ginger, and red...
#
#                                                   url Additional Time
# 0   https://www.allrecipes.com/recipe/212721/india...             NaN
# 1   https://www.allrecipes.com/recipe/223382/chick...             NaN
# 2   https://www.allrecipes.com/recipe/31848/jambal...             NaN
# 3   https://www.allrecipes.com/recipe/72068/chicke...             NaN
# 4   https://www.allrecipes.com/recipe/240208/simpl...             NaN
# 5   https://www.allrecipes.com/recipe/8887/chicken...             NaN
# 6   https://www.allrecipes.com/recipe/55860/baked-...             NaN
# 7   https://www.allrecipes.com/recipe/61024/asian-...   2 hrs 10 mins
# 8   https://www.allrecipes.com/recipe/21659/chicke...             NaN
# 9   https://www.allrecipes.com/recipe/8495/chicken...             NaN
# 10  https://www.allrecipes.com/recipe/8941/slow-co...             NaN
# 11  https://www.allrecipes.com/recipe/84137/easy-p...             NaN
# 12  https://www.allrecipes.com/recipe/8463459/air-...             NaN
# 13  https://www.allrecipes.com/recipe/187342/banh-mi/             NaN
# 14  https://www.allrecipes.com/recipe/17745/easy-i...           1 hrs
# 15  https://www.allrecipes.com/recipe/8626/yummy-h...           2 hrs
# 16  https://www.allrecipes.com/recipe/11864/chicke...             NaN
# 17  https://www.allrecipes.com/recipe/220326/sarah...         10 mins
# 18  https://www.allrecipes.com/recipe/8849/baked-c...             NaN
# 19  https://www.allrecipes.com/recipe/46982/pesto-...             NaN
# 20  https://www.allrecipes.com/recipe/141169/easy-...             NaN
# 21  https://www.allrecipes.com/recipe/8571/blacken...             NaN
# 22  https://www.allrecipes.com/recipe/8778/cajun-c...             NaN
# 23  https://www.allrecipes.com/recipe/236703/chef-...         45 mins
# 24  https://www.allrecipes.com/recipe/9027/kung-pa...         30 mins
# 25  https://www.allrecipes.com/recipe/159972/tende...         10 mins
# 26  https://www.allrecipes.com/recipe/216902/poppy...             NaN
# 27  https://www.allrecipes.com/recipe/231939/honey...             NaN
# 28  https://www.allrecipes.com/recipe/46822/indian...             NaN
# 29  https://www.allrecipes.com/recipe/151266/bonel...         20 mins
# 30  https://www.allrecipes.com/recipe/15181/famous...             NaN
# 31  https://www.allrecipes.com/recipe/70638/oven-r...             NaN
# 32  https://www.allrecipes.com/recipe/244950/baked...             NaN
# 33  https://www.allrecipes.com/recipe/279837/chees...             NaN
# 34  https://www.allrecipes.com/recipe/228650/easy-...             NaN
# 35  https://www.allrecipes.com/recipe/239428/crisp...             NaN
# 36  https://www.allrecipes.com/recipe/241890/grill...           4 hrs
# 37  https://www.allrecipes.com/recipe/8691/chicken...         10 mins
# 38  https://www.allrecipes.com/recipe/235111/slow-...             NaN
# 39  https://www.allrecipes.com/recipe/239137/three...             NaN
# 40  https://www.allrecipes.com/recipe/13087/mullig...             NaN
# 41  https://www.allrecipes.com/recipe/8919/grilled...         20 mins
# 42  https://www.allrecipes.com/recipe/231644/chick...           2 hrs
# 43  https://www.allrecipes.com/recipe/176132/slow-...             NaN
# 44  https://www.allrecipes.com/recipe/214488/lemon...             NaN
# 45  https://www.allrecipes.com/recipe/65896/zesty-...             NaN
# 46  https://www.allrecipes.com/recipe/220751/quick...             NaN
# 47  https://www.allrecipes.com/recipe/219431/parme...             NaN
# 48  https://www.allrecipes.com/recipe/278806/air-f...          5 mins
# 49  https://www.allrecipes.com/recipe/45736/chicke...           1 hrs
# 50  https://www.allrecipes.com/recipe/8847/baked-h...         10 mins
# 51  https://www.allrecipes.com/recipe/278708/air-f...             NaN
# 52  https://www.allrecipes.com/recipe/16700/salsa-...             NaN
# 53  https://www.allrecipes.com/recipe/231174/easy-...           4 hrs
# 54  https://www.allrecipes.com/recipe/70343/slow-c...             NaN
# 55  https://www.allrecipes.com/recipe/228293/curry...             NaN
# 56    https://www.allrecipes.com/recipe/17904/kabobs/           4 hrs
# 57  https://www.allrecipes.com/recipe/220416/chef-...             NaN
# 58  https://www.allrecipes.com/recipe/240708/brocc...             NaN

# %%
df2.describe()
# Out:
#              Row   Servings
# count  59.000000  59.000000
# mean   29.000000   5.491525
# std    17.175564   2.184371
# min     0.000000   2.000000
# 25%    14.500000   4.000000
# 50%    29.000000   6.000000
# 75%    43.500000   6.000000
# max    58.000000  12.000000

# %%
df2.isna().sum()
# Out:
# Row                 0
# Name                0
# Prep Time           0
# Cook Time           0
# Total Time          0
# Servings            0
# Yield              44
# Ingredients         0
# Directions          0
# url                 0
# Additional Time    42
# dtype: int64

# %%
#Dropping the yield column since its similar to the servings
#Dropping the cook_time and prep_time
df2.drop(['Prep Time','Cook Time','Yield','Additional Time'], axis=1, inplace=True)

# %%
#Extracting the ingredients, unit and quantity
dict_df = pd.DataFrame([ast.literal_eval(i) for i in df2.Ingredients.values])

# %%
dict_df
# Out:
#                                                    0   \
# 0   {'quantity': '2', 'unit': 'pounds', 'name': 's...
# 1   {'quantity': '4', 'unit': 'cups', 'name': 'wat...
# 2   {'quantity': '2', 'unit': 'tablespoons', 'name...
# 3   {'quantity': '4', 'unit': '', 'name': 'skinles...
# 4   {'quantity': '4', 'unit': '(5 ounce)', 'name':...
# 5   {'quantity': '¼', 'unit': 'cup', 'name': 'all-...
# 6   {'quantity': '2', 'unit': 'tablespoons', 'name...
# 7   {'quantity': '1 ½', 'unit': 'cups', 'name': 'w...
# 8   {'quantity': '1', 'unit': 'pound', 'name': 'sk...
# 9   {'quantity': '', 'unit': '', 'name': 'nonstick...
# 10  {'quantity': '4', 'unit': '', 'name': 'skinles...
# 11  {'quantity': '2', 'unit': 'tablespoons', 'name...
# 12  {'quantity': '25', 'unit': 'ounces', 'name': '...
# 13  {'quantity': '½', 'unit': 'cup', 'name': 'rice...
# 14  {'quantity': '1', 'unit': '(16 ounce) bottle',...
# 15  {'quantity': '⅓', 'unit': 'cup', 'name': 'honey'}
# 16  {'quantity': '4', 'unit': '', 'name': 'skinles...
# 17  {'quantity': '1', 'unit': 'pound', 'name': 'sk...
# 18  {'quantity': '3', 'unit': '', 'name': 'skinles...
# 19  {'quantity': '1', 'unit': '(16 ounce) package'...
# 20  {'quantity': '1', 'unit': 'cup', 'name': 'butt...
# 21  {'quantity': '½', 'unit': 'teaspoon', 'name': ...
# 22  {'quantity': '4', 'unit': 'ounces', 'name': 'l...
# 23  {'quantity': '2', 'unit': 'cloves', 'name': 'g...
# 24  {'quantity': '2', 'unit': 'tablespoons', 'name...
# 25  {'quantity': '2', 'unit': 'cups', 'name': 'flo...
# 26  {'quantity': '4', 'unit': '', 'name': 'skinles...
# 27  {'quantity': '¼', 'unit': 'cup', 'name': 'honey'}
# 28  {'quantity': '3', 'unit': 'tablespoons', 'name...
# 29  {'quantity': '', 'unit': '', 'name': 'oil for ...
# 30  {'quantity': '1', 'unit': 'large', 'name': 'eg...
# 31  {'quantity': '1', 'unit': 'cup', 'name': 'part...
# 32  {'quantity': '1', 'unit': 'tablespoon', 'name'...
# 33  {'quantity': '1', 'unit': 'teaspoon', 'name': ...
# 34  {'quantity': '1', 'unit': 'tablespoon', 'name'...
# 35  {'quantity': '1', 'unit': 'pound', 'name': 'bo...
# 36  {'quantity': '¼', 'unit': 'cup', 'name': 'red ...
# 37  {'quantity': '1', 'unit': 'tablespoon', 'name'...
# 38  {'quantity': '4', 'unit': '', 'name': 'skinles...
# 39  {'quantity': '¼', 'unit': 'cup', 'name': 'butt...
# 40  {'quantity': '½', 'unit': 'cup', 'name': 'chop...
# 41  {'quantity': '¼', 'unit': 'cup', 'name': 'soy ...
# 42  {'quantity': '¼', 'unit': 'cup', 'name': 'oliv...
# 43  {'quantity': '4', 'unit': '', 'name': 'skinles...
# 44  {'quantity': '3', 'unit': 'large', 'name': 'sk...
# 45  {'quantity': '6', 'unit': '', 'name': 'frozen ...
# 46  {'quantity': '4', 'unit': '', 'name': 'skinles...
# 47  {'quantity': '½', 'unit': 'cup', 'name': 'Hell...
# 48  {'quantity': '2', 'unit': '', 'name': 'boneles...
# 49  {'quantity': '1', 'unit': 'cup', 'name': 'yogu...
# 50  {'quantity': '', 'unit': '', 'name': 'cooking ...
# 51  {'quantity': '½', 'unit': 'cup', 'name': 'ketc...
# 52  {'quantity': '4', 'unit': '', 'name': 'skinles...
# 53  {'quantity': '½', 'unit': 'cup', 'name': 'vege...
# 54  {'quantity': '2', 'unit': '(10 ounce) cans', '...
# 55  {'quantity': '2', 'unit': 'tablespoons', 'name...
# 56  {'quantity': '½', 'unit': 'cup', 'name': 'teri...
# 57  {'quantity': '1', 'unit': 'tablespoon', 'name'...
# 58  {'quantity': '⅔', 'unit': 'cup', 'name': 'soy ...
#
#                                                    1   \
# 0   {'quantity': '2', 'unit': 'teaspoons', 'name':...
# 1   {'quantity': '2', 'unit': 'cups', 'name': 'whi...
# 2   {'quantity': '1', 'unit': 'tablespoon', 'name'...
# 3   {'quantity': '', 'unit': '', 'name': 'salt and...
# 4   {'quantity': '2', 'unit': 'tablespoons', 'name...
# 5   {'quantity': '½', 'unit': 'teaspoon', 'name': ...
# 6   {'quantity': '1', 'unit': 'clove', 'name': 'ga...
# 7   {'quantity': '⅓', 'unit': 'cup', 'name': 'rice...
# 8   {'quantity': '1', 'unit': '(1.27 ounce) packet...
# 9   {'quantity': '4', 'unit': '', 'name': 'skinles...
# 10  {'quantity': '2', 'unit': 'tablespoons', 'name...
# 11  {'quantity': '1', 'unit': 'tablespoon', 'name'...
# 12                                               None
# 13  {'quantity': '¼', 'unit': 'cup', 'name': 'whit...
# 14  {'quantity': '6', 'unit': '', 'name': 'skinles...
# 15  {'quantity': '⅓', 'unit': 'cup', 'name': 'soy ...
# 16  {'quantity': '6', 'unit': 'ounces', 'name': 'e...
# 17  {'quantity': '2', 'unit': 'teaspoons', 'name':...
# 18  {'quantity': '1', 'unit': 'cup', 'name': 'Ital...
# 19  {'quantity': '1', 'unit': 'teaspoon', 'name': ...
# 20  {'quantity': '1', 'unit': '', 'name': 'onion, ...
# 21  {'quantity': '¼', 'unit': 'teaspoon', 'name': ...
# 22  {'quantity': '2', 'unit': '', 'name': 'skinles...
# 23  {'quantity': '1', 'unit': 'pinch', 'name': 'sa...
# 24  {'quantity': '2', 'unit': 'tablespoons', 'name...
# 25  {'quantity': '2', 'unit': 'tablespoons', 'name...
# 26  {'quantity': '1', 'unit': 'sleeve', 'name': 'b...
# 27  {'quantity': '2', 'unit': 'tablespoons', 'name...
# 28  {'quantity': '1', 'unit': 'small', 'name': 'on...
# 29  {'quantity': '1', 'unit': 'cup', 'name': 'unbl...
# 30  {'quantity': '1 ½', 'unit': 'medium', 'name': ...
# 31  {'quantity': '¾', 'unit': 'cup', 'name': 'fine...
# 32  {'quantity': '6', 'unit': '', 'name': 'chicken...
# 33  {'quantity': '2', 'unit': '', 'name': 'skinles...
# 34  {'quantity': '3', 'unit': '', 'name': 'skinles...
# 35       {'quantity': '1', 'unit': '', 'name': 'egg'}
# 36  {'quantity': '¼', 'unit': 'cup', 'name': 'redu...
# 37  {'quantity': '4', 'unit': '', 'name': 'skinles...
# 38  {'quantity': '1', 'unit': '(18 ounce) bottle',...
# 39  {'quantity': '1', 'unit': 'teaspoon', 'name': ...
# 40  {'quantity': '2', 'unit': 'stalks', 'name': 'c...
# 41  {'quantity': '2', 'unit': 'tablespoons', 'name...
# 42  {'quantity': '2', 'unit': 'cloves', 'name': 'g...
# 43  {'quantity': '1', 'unit': '(17.5 fluid ounce) ...
# 44  {'quantity': '', 'unit': '', 'name': 'salt and...
# 45  {'quantity': '1', 'unit': '(12 ounce) bottle',...
# 46  {'quantity': '', 'unit': '', 'name': 'cayenne ...
# 47  {'quantity': '¼', 'unit': 'cup', 'name': 'grat...
# 48  {'quantity': '', 'unit': '', 'name': 'salt and...
# 49  {'quantity': '1', 'unit': 'tablespoon', 'name'...
# 50  {'quantity': '6', 'unit': '', 'name': 'skinles...
# 51  {'quantity': '2', 'unit': 'tablespoons', 'name...
# 52  {'quantity': '4', 'unit': 'teaspoons', 'name':...
# 53  {'quantity': '2', 'unit': 'tablespoons', 'name...
# 54  {'quantity': '1', 'unit': '(16 ounce) can', 'n...
# 55  {'quantity': '1', 'unit': '', 'name': 'onion, ...
# 56  {'quantity': '½', 'unit': 'cup', 'name': 'honey'}
# 57  {'quantity': '½', 'unit': 'cup', 'name': 'dice...
# 58  {'quantity': '¼', 'unit': 'cup', 'name': 'brow...
#
#                                                    2   \
# 0   {'quantity': '½', 'unit': 'cup', 'name': 'cook...
# 1   {'quantity': '⅔', 'unit': 'cup', 'name': 'soy ...
# 2   {'quantity': '10', 'unit': 'ounces', 'name': '...
# 3   {'quantity': '2', 'unit': 'tablespoons', 'name...
# 4   {'quantity': '½', 'unit': 'teaspoon', 'name': ...
# 5   {'quantity': '¼', 'unit': 'teaspoon', 'name': ...
# 6   {'quantity': '1', 'unit': 'cup', 'name': 'dry ...
# 7   {'quantity': '¼', 'unit': 'cup', 'name': 'lemo...
# 8   {'quantity': '1', 'unit': 'tablespoon', 'name'...
# 9   {'quantity': '¼', 'unit': 'teaspoon', 'name': ...
# 10  {'quantity': '2', 'unit': '(10.5 ounce) cans',...
# 11  {'quantity': '2', 'unit': 'teaspoons', 'name':...
# 12                                               None
# 13  {'quantity': '¼', 'unit': 'cup', 'name': 'water'}
# 14                                               None
# 15  {'quantity': '¼', 'unit': 'cup', 'name': 'vege...
# 16  {'quantity': '1', 'unit': '(10.5 ounce) can', ...
# 17  {'quantity': '1', 'unit': 'tablespoon', 'name'...
# 18  {'quantity': '½', 'unit': 'cup', 'name': 'grat...
# 19  {'quantity': '2', 'unit': 'cloves', 'name': 'g...
# 20  {'quantity': '1', 'unit': 'tablespoon', 'name'...
# 21  {'quantity': '¼', 'unit': 'teaspoon', 'name': ...
# 22  {'quantity': '2', 'unit': 'teaspoons', 'name':...
# 23  {'quantity': '2', 'unit': 'tablespoons', 'name...
# 24  {'quantity': '2', 'unit': 'tablespoons', 'name...
# 25  {'quantity': '2', 'unit': 'tablespoons', 'name...
# 26  {'quantity': '½', 'unit': 'cup', 'name': 'butt...
# 27  {'quantity': '⅛', 'unit': 'teaspoon', 'name': ...
# 28  {'quantity': '2', 'unit': 'cloves', 'name': 'g...
# 29  {'quantity': '2', 'unit': 'teaspoons', 'name':...
# 30  {'quantity': '1', 'unit': 'cup', 'name': 'all-...
# 31  {'quantity': '½', 'unit': 'cup', 'name': 'grat...
# 32  {'quantity': '', 'unit': '', 'name': 'salt and...
# 33  {'quantity': '3', 'unit': 'cups', 'name': 'fin...
# 34  {'quantity': '1', 'unit': 'large', 'name': 'on...
# 35  {'quantity': '1', 'unit': 'cup', 'name': 'pank...
# 36  {'quantity': '¼', 'unit': 'cup', 'name': 'oliv...
# 37  {'quantity': '1', 'unit': '', 'name': 'onion, ...
# 38  {'quantity': '¼', 'unit': 'cup', 'name': 'dist...
# 39  {'quantity': '4', 'unit': '', 'name': 'skinles...
# 40  {'quantity': '1', 'unit': '', 'name': 'carrot,...
# 41  {'quantity': '4', 'unit': 'teaspoons', 'name':...
# 42  {'quantity': '2', 'unit': 'tablespoons', 'name...
# 43  {'quantity': '½', 'unit': '(1 ounce) package',...
# 44  {'quantity': '½', 'unit': 'cup', 'name': 'all-...
# 45  {'quantity': '½', 'unit': 'cup', 'name': 'Ital...
# 46  {'quantity': '', 'unit': '', 'name': 'salt and...
# 47  {'quantity': '4', 'unit': '(5 ounce)', 'name':...
# 48  {'quantity': '1', 'unit': 'tablespoon', 'name'...
# 49  {'quantity': '4', 'unit': 'teaspoons', 'name':...
# 50  {'quantity': '', 'unit': '', 'name': 'salt and...
# 51  {'quantity': '1', 'unit': 'tablespoon', 'name'...
# 52  {'quantity': '1', 'unit': 'cup', 'name': 'salsa'}
# 53  {'quantity': '2', 'unit': 'tablespoons', 'name...
# 54  {'quantity': '1', 'unit': '(15 ounce) can', 'n...
# 55  {'quantity': '4', 'unit': 'cloves', 'name': 'g...
# 56  {'quantity': '½', 'unit': 'teaspoon', 'name': ...
# 57  {'quantity': '½', 'unit': 'cup', 'name': 'dice...
# 58  {'quantity': '½', 'unit': 'teaspoon', 'name': ...
#
#                                                    3   \
# 0   {'quantity': '1 ½', 'unit': 'cups', 'name': 'c...
# 1   {'quantity': '¼', 'unit': 'cup', 'name': 'brow...
# 2   {'quantity': '1', 'unit': 'pound', 'name': 'bo...
# 3   {'quantity': '1', 'unit': '', 'name': 'egg, be...
# 4   {'quantity': '1', 'unit': 'pinch', 'name': 'Cr...
# 5   {'quantity': '½', 'unit': 'teaspoon', 'name': ...
# 6   {'quantity': '⅔', 'unit': 'cup', 'name': 'grat...
# 7   {'quantity': '2 ½', 'unit': 'tablespoons', 'na...
# 8   {'quantity': '2', 'unit': '', 'name': 'green b...
# 9   {'quantity': '⅛', 'unit': 'teaspoon', 'name': ...
# 10  {'quantity': '1', 'unit': 'medium', 'name': 'o...
# 11  {'quantity': '', 'unit': '', 'name': 'salt and...
# 12                                               None
# 13  {'quantity': '¼', 'unit': 'cup', 'name': 'matc...
# 14                                               None
# 15  {'quantity': '¼', 'unit': 'teaspoon', 'name': ...
# 16  {'quantity': '1', 'unit': '(10.5 ounce) can', ...
# 17  {'quantity': '¼', 'unit': 'cup', 'name': 'toma...
# 18  {'quantity': '1', 'unit': 'tablespoon', 'name'...
# 19  {'quantity': '2', 'unit': '', 'name': 'skinles...
# 20  {'quantity': '1', 'unit': '(15 ounce) can', 'n...
# 21  {'quantity': '¼', 'unit': 'teaspoon', 'name': ...
# 22  {'quantity': '2', 'unit': 'tablespoons', 'name...
# 23  {'quantity': '6', 'unit': 'tablespoons', 'name...
# 24  {'quantity': '2', 'unit': 'tablespoons', 'name...
# 25  {'quantity': '1', 'unit': 'tablespoon', 'name'...
# 26  {'quantity': '1', 'unit': 'teaspoon', 'name': ...
# 27  {'quantity': '1 ½', 'unit': 'tablespoons', 'na...
# 28  {'quantity': '3', 'unit': 'tablespoons', 'name...
# 29  {'quantity': '½', 'unit': 'teaspoon', 'name': ...
# 30  {'quantity': '1', 'unit': 'pinch', 'name': 'ga...
# 31  {'quantity': '½', 'unit': 'cup', 'name': 'dry ...
# 32  {'quantity': '¾', 'unit': 'cup', 'name': 'all-...
# 33  {'quantity': '2', 'unit': '(10.5 ounce) cans',...
# 34  {'quantity': '2', 'unit': 'cloves', 'name': 'g...
# 35  {'quantity': '½', 'unit': 'teaspoon', 'name': ...
# 36  {'quantity': '1 ½', 'unit': 'teaspoons', 'name...
# 37  {'quantity': '1 ¾', 'unit': 'cups', 'name': 's...
# 38  {'quantity': '¼', 'unit': 'cup', 'name': 'brow...
# 39                                               None
# 40  {'quantity': '¼', 'unit': 'cup', 'name': 'butt...
# 41  {'quantity': '2', 'unit': 'cloves', 'name': 'g...
# 42  {'quantity': '1', 'unit': 'teaspoon', 'name': ...
# 43  {'quantity': '2', 'unit': 'tablespoons', 'name...
# 44  {'quantity': '2', 'unit': 'tablespoons', 'name...
# 45  {'quantity': '¼', 'unit': 'cup', 'name': 'brow...
# 46  {'quantity': '', 'unit': '', 'name': 'all-purp...
# 47  {'quantity': '4', 'unit': 'teaspoons', 'name':...
# 48  {'quantity': '4', 'unit': 'slices', 'name': 'd...
# 49  {'quantity': '1', 'unit': 'teaspoon', 'name': ...
# 50  {'quantity': '½', 'unit': 'cup', 'name': 'honey'}
# 51  {'quantity': '1', 'unit': 'tablespoon', 'name'...
# 52  {'quantity': '1', 'unit': 'cup', 'name': 'shre...
# 53  {'quantity': '2', 'unit': 'tablespoons', 'name...
# 54  {'quantity': '1', 'unit': '(15 ounce) can', 'n...
# 55  {'quantity': '1', 'unit': 'tablespoon', 'name'...
# 56  {'quantity': '½', 'unit': 'pinch', 'name': 'gr...
# 57  {'quantity': '½', 'unit': 'cup', 'name': 'dice...
# 58  {'quantity': '1', 'unit': 'pinch', 'name': 're...
#
#                                                    4   \
# 0   {'quantity': '1', 'unit': 'tablespoon', 'name'...
# 1   {'quantity': '1', 'unit': 'tablespoon', 'name'...
# 2   {'quantity': '1', 'unit': '', 'name': 'onion, ...
# 3   {'quantity': '1', 'unit': 'cup', 'name': 'pank...
# 4   {'quantity': '1', 'unit': 'tablespoon', 'name'...
# 5   {'quantity': '4', 'unit': 'medium', 'name': 's...
# 6   {'quantity': '1', 'unit': 'teaspoon', 'name': ...
# 7   {'quantity': '2', 'unit': 'tablespoons', 'name...
# 8   {'quantity': '2', 'unit': '', 'name': 'red bel...
# 9   {'quantity': '6', 'unit': 'slices', 'name': 'S...
# 10  {'quantity': '1', 'unit': '(10 ounce) package'...
# 11                                               None
# 12                                               None
# 13  {'quantity': '¼', 'unit': 'cup', 'name': 'peel...
# 14                                               None
# 15                                               None
# 16  {'quantity': '1', 'unit': 'cup', 'name': 'sour...
# 17  {'quantity': '1', 'unit': 'pinch', 'name': 'gr...
# 18  {'quantity': '1', 'unit': 'teaspoon', 'name': ...
# 19  {'quantity': '1', 'unit': 'pinch', 'name': 'cr...
# 20  {'quantity': '3', 'unit': 'cups', 'name': 'hea...
# 21  {'quantity': '⅛', 'unit': 'teaspoon', 'name': ...
# 22  {'quantity': '1', 'unit': '', 'name': 'red bel...
# 23  {'quantity': '4', 'unit': '(8 ounce)', 'name':...
# 24  {'quantity': '1', 'unit': 'pound', 'name': 'sk...
# 25  {'quantity': '1', 'unit': 'tablespoon', 'name'...
# 26  {'quantity': '1', 'unit': '(10.75 ounce) can '...
# 27  {'quantity': '2', 'unit': '', 'name': 'skinles...
# 28  {'quantity': '1', 'unit': 'teaspoon', 'name': ...
# 29  {'quantity': '½', 'unit': 'teaspoon', 'name': ...
# 30  {'quantity': '1', 'unit': 'pinch', 'name': 'pa...
# 31  {'quantity': '1', 'unit': 'teaspoon', 'name': ...
# 32  {'quantity': '1', 'unit': 'tablespoon', 'name'...
# 33  {'quantity': '1', 'unit': 'cup', 'name': 'shre...
# 34  {'quantity': '5 ¼', 'unit': 'cups', 'name': 'c...
# 35  {'quantity': '½', 'unit': 'teaspoon', 'name': ...
# 36  {'quantity': '½', 'unit': 'teaspoon', 'name': ...
# 37  {'quantity': '½', 'unit': 'pint', 'name': 'sou...
# 38  {'quantity': '1', 'unit': 'teaspoon', 'name': ...
# 39                                               None
# 40  {'quantity': '1 ½', 'unit': 'tablespoons', 'na...
# 41  {'quantity': '3', 'unit': 'slices', 'name': 'f...
# 42  {'quantity': '½', 'unit': 'teaspoon', 'name': ...
# 43  {'quantity': '6', 'unit': '', 'name': 'hoagie ...
# 44  {'quantity': '1', 'unit': 'clove', 'name': 'ga...
# 45  {'quantity': '2', 'unit': 'tablespoons', 'name...
# 46  {'quantity': '2', 'unit': 'tablespoons', 'name...
# 47                                               None
# 48  {'quantity': '4', 'unit': 'slices', 'name': 'd...
# 49  {'quantity': '2', 'unit': 'teaspoons', 'name':...
# 50  {'quantity': '½', 'unit': 'cup', 'name': 'prep...
# 51  {'quantity': '2', 'unit': 'teaspoons', 'name':...
# 52  {'quantity': '2', 'unit': 'tablespoons', 'name...
# 53  {'quantity': '2', 'unit': 'tablespoons', 'name...
# 54  {'quantity': '1', 'unit': '(12 fluid ounce) ca...
# 55  {'quantity': '1', 'unit': 'teaspoon', 'name': ...
# 56  {'quantity': '1 ½', 'unit': 'pounds', 'name': ...
# 57  {'quantity': '¼', 'unit': 'teaspoon', 'name': ...
# 58  {'quantity': '2', 'unit': 'tablespoons', 'name...
#
#                                                    5   \
# 0   {'quantity': '1 ½', 'unit': 'teaspoons', 'name...
# 1   {'quantity': '1', 'unit': 'tablespoon', 'name'...
# 2   {'quantity': '1', 'unit': 'small', 'name': 'gr...
# 3   {'quantity': '1', 'unit': 'cup', 'name': 'oil ...
# 4                                                None
# 5   {'quantity': '4', 'unit': 'tablespoons', 'name...
# 6   {'quantity': '¼', 'unit': 'teaspoon', 'name': ...
# 7   {'quantity': '1', 'unit': 'cup', 'name': 'pack...
# 8   {'quantity': '1', 'unit': '', 'name': 'onion, ...
# 9   {'quantity': '4', 'unit': 'slices', 'name': 'c...
# 10  {'quantity': '2', 'unit': 'cups', 'name': 'wat...
# 11                                               None
# 12                                               None
# 13  {'quantity': '¼', 'unit': 'cup', 'name': 'thin...
# 14                                               None
# 15                                               None
# 16  {'quantity': '', 'unit': '', 'name': 'salt to ...
# 17  {'quantity': '1', 'unit': 'pinch', 'name': 'ch...
# 18  {'quantity': '1', 'unit': 'teaspoon', 'name': ...
# 19  {'quantity': '½', 'unit': 'cup', 'name': 'pest...
# 20  {'quantity': '2', 'unit': 'teaspoons', 'name':...
# 21  {'quantity': '⅛', 'unit': 'teaspoon', 'name': ...
# 22  {'quantity': '1', 'unit': '', 'name': 'green b...
# 23  {'quantity': '', 'unit': '', 'name': 'salt and...
# 24  {'quantity': '1', 'unit': 'ounce', 'name': 'ho...
# 25  {'quantity': '1', 'unit': 'tablespoon', 'name'...
# 26  {'quantity': '1', 'unit': '(8 ounce) container...
# 27                                               None
# 28  {'quantity': '1', 'unit': 'teaspoon', 'name': ...
# 29  {'quantity': '½', 'unit': 'teaspoon', 'name': ...
# 30  {'quantity': '6', 'unit': '', 'name': 'skinles...
# 31  {'quantity': '6', 'unit': '', 'name': 'boneles...
# 32  {'quantity': '2', 'unit': 'large', 'name': 'eg...
# 33  {'quantity': '1', 'unit': 'cup', 'name': 'shre...
# 34  {'quantity': '3', 'unit': '(15 ounce) cans', '...
# 35  {'quantity': '½', 'unit': 'teaspoon', 'name': ...
# 36  {'quantity': '½', 'unit': 'teaspoon', 'name': ...
# 37  {'quantity': '1', 'unit': 'tablespoon', 'name'...
# 38  {'quantity': '½', 'unit': 'teaspoon', 'name': ...
# 39                                               None
# 40  {'quantity': '1 ½', 'unit': 'teaspoons', 'name...
# 41  {'quantity': '4', 'unit': '', 'name': 'skinles...
# 42  {'quantity': '1 ½', 'unit': 'pounds', 'name': ...
# 43                                               None
# 44  {'quantity': '1', 'unit': 'cup', 'name': 'low ...
# 45                                               None
# 46  {'quantity': '1', 'unit': 'tablespoon', 'name'...
# 47                                               None
# 48  {'quantity': '', 'unit': '', 'name': '2 toothp...
# 49  {'quantity': '2', 'unit': 'teaspoons', 'name':...
# 50  {'quantity': '1', 'unit': 'teaspoon', 'name': ...
# 51  {'quantity': '1', 'unit': 'teaspoon', 'name': ...
# 52                                               None
# 53  {'quantity': '½', 'unit': 'teaspoon', 'name': ...
# 54  {'quantity': '1', 'unit': '(8 ounce) can', 'na...
# 55  {'quantity': '1', 'unit': 'teaspoon', 'name': ...
# 56  {'quantity': '1', 'unit': 'pound', 'name': 'be...
# 57  {'quantity': '1', 'unit': 'pinch', 'name': 'sa...
# 58  {'quantity': '2', 'unit': 'tablespoons', 'name...
#
#                                                    6   \
# 0   {'quantity': '1', 'unit': 'tablespoon', 'name'...
# 1   {'quantity': '1', 'unit': 'tablespoon', 'name'...
# 2   {'quantity': '2', 'unit': 'stalks', 'name': 'c...
# 3                                                None
# 4                                                None
# 5   {'quantity': '4', 'unit': 'tablespoons', 'name...
# 6   {'quantity': '6', 'unit': '', 'name': 'skinles...
# 7   {'quantity': '2', 'unit': 'tablespoons', 'name...
# 8   {'quantity': '10', 'unit': '(10 inch)', 'name'...
# 9   {'quantity': '½', 'unit': 'cup', 'name': 'seas...
# 10                                               None
# 11                                               None
# 12                                               None
# 13  {'quantity': '1', 'unit': '', 'name': 'skinles...
# 14                                               None
# 15                                               None
# 16  {'quantity': '', 'unit': '', 'name': 'ground b...
# 17                                               None
# 18  {'quantity': '½', 'unit': 'cup', 'name': 'butt...
# 19  {'quantity': '⅓', 'unit': 'cup', 'name': 'oil-...
# 20  {'quantity': '1', 'unit': 'teaspoon', 'name': ...
# 21  {'quantity': '⅛', 'unit': 'teaspoon', 'name': ...
# 22  {'quantity': '4', 'unit': '', 'name': 'fresh m...
# 23  {'quantity': '1', 'unit': 'cup', 'name': 'all-...
# 24  {'quantity': '2', 'unit': 'teaspoons', 'name':...
# 25  {'quantity': '1', 'unit': 'tablespoon', 'name'...
# 26  {'quantity': '2', 'unit': 'cups', 'name': 'shr...
# 27                                               None
# 28  {'quantity': '1', 'unit': '', 'name': 'bay leaf'}
# 29  {'quantity': '¼', 'unit': 'teaspoon', 'name': ...
# 30  {'quantity': '2', 'unit': 'tablespoons', 'name...
# 31  {'quantity': '2', 'unit': 'tablespoons', 'name...
# 32  {'quantity': '2', 'unit': 'cups', 'name': 'sea...
# 33  {'quantity': '½', 'unit': 'cup', 'name': 'shre...
# 34  {'quantity': '2', 'unit': '(4 ounce) cans', 'n...
# 35  {'quantity': '¼', 'unit': 'teaspoon', 'name': ...
# 36  {'quantity': '¼', 'unit': 'teaspoon', 'name': ...
# 37  {'quantity': '½', 'unit': 'teaspoon', 'name': ...
# 38                                               None
# 39                                               None
# 40  {'quantity': '4', 'unit': 'cups', 'name': 'chi...
# 41                                               None
# 42  {'quantity': '6', 'unit': '', 'name': 'wooden ...
# 43                                               None
# 44  {'quantity': '½', 'unit': '', 'name': 'lemon, ...
# 45                                               None
# 46  {'quantity': '½', 'unit': 'cup', 'name': 'whit...
# 47                                               None
# 48  {'quantity': '¼', 'unit': 'cup', 'name': 'all-...
# 49  {'quantity': '1', 'unit': 'tablespoon', 'name'...
# 50  {'quantity': '1', 'unit': 'teaspoon', 'name': ...
# 51                                               None
# 52                                               None
# 53  {'quantity': '½', 'unit': 'teaspoon', 'name': ...
# 54  {'quantity': '1', 'unit': '', 'name': 'onion, ...
# 55  {'quantity': '1', 'unit': 'teaspoon', 'name': ...
# 56  {'quantity': '2', 'unit': '', 'name': 'red bel...
# 57  {'quantity': '2', 'unit': 'tablespoons', 'name...
# 58  {'quantity': '2', 'unit': 'teaspoons', 'name':...
#
#                                                    7   \
# 0   {'quantity': '1', 'unit': 'teaspoon', 'name': ...
# 1   {'quantity': '¼', 'unit': 'teaspoon', 'name': ...
# 2   {'quantity': '3', 'unit': 'cloves', 'name': 'g...
# 3                                                None
# 4                                                None
# 5   {'quantity': '1', 'unit': 'cup', 'name': 'slic...
# 6                                                None
# 7   {'quantity': '1', 'unit': 'tablespoon', 'name'...
# 8   {'quantity': '1', 'unit': '(8 ounce) package',...
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13  {'quantity': '1', 'unit': 'pinch', 'name': 'ga...
# 14                                               None
# 15                                               None
# 16  {'quantity': '½', 'unit': 'cup', 'name': 'butt...
# 17                                               None
# 18                                               None
# 19                                               None
# 20  {'quantity': '1', 'unit': 'teaspoon', 'name': ...
# 21  {'quantity': '2', 'unit': '', 'name': 'skinles...
# 22  {'quantity': '1', 'unit': '', 'name': 'green o...
# 23  {'quantity': '2', 'unit': 'teaspoons', 'name':...
# 24  {'quantity': '1', 'unit': 'teaspoon', 'name': ...
# 25  {'quantity': '1', 'unit': 'teaspoon', 'name': ...
# 26                                               None
# 27                                               None
# 28  {'quantity': '½', 'unit': 'teaspoon', 'name': ...
# 29       {'quantity': '1', 'unit': '', 'name': 'egg'}
# 30  {'quantity': '1', 'unit': '(14.5 ounce) can', ...
# 31                                               None
# 32  {'quantity': '1', 'unit': 'large', 'name': 'le...
# 33  {'quantity': '½', 'unit': 'cup', 'name': 'sour...
# 34  {'quantity': '1', 'unit': 'tablespoon', 'name'...
# 35  {'quantity': '¼', 'unit': 'cup', 'name': 'Mazo...
# 36  {'quantity': '¼', 'unit': 'teaspoon', 'name': ...
# 37  {'quantity': '½', 'unit': 'teaspoon', 'name': ...
# 38                                               None
# 39                                               None
# 40  {'quantity': '½', 'unit': '', 'name': 'apple, ...
# 41                                               None
# 42                                               None
# 43                                               None
# 44  {'quantity': '¼', 'unit': 'cup', 'name': 'fres...
# 45                                               None
# 46  {'quantity': '¼', 'unit': 'cup', 'name': 'fres...
# 47                                               None
# 48  {'quantity': '1', 'unit': '', 'name': 'egg, be...
# 49  {'quantity': '2', 'unit': 'teaspoons', 'name':...
# 50  {'quantity': '½', 'unit': 'teaspoon', 'name': ...
# 51                                               None
# 52                                               None
# 53  {'quantity': '3', 'unit': 'pounds', 'name': 's...
# 54  {'quantity': '1', 'unit': '(1.25 ounce) packag...
# 55  {'quantity': '½', 'unit': 'teaspoon', 'name': ...
# 56  {'quantity': '1', 'unit': 'large', 'name': 'sw...
# 57  {'quantity': '2', 'unit': 'quarts', 'name': 'r...
# 58  {'quantity': '3', 'unit': '', 'name': 'skinles...
#
#                                                    8   \
# 0   {'quantity': '1', 'unit': 'teaspoon', 'name': ...
# 1   {'quantity': '3', 'unit': '', 'name': 'skinles...
# 2   {'quantity': '1', 'unit': '(16 ounce) can', 'n...
# 3                                                None
# 4                                                None
# 5   {'quantity': '½', 'unit': 'cup', 'name': 'Mars...
# 6                                                None
# 7   {'quantity': '½', 'unit': 'teaspoon', 'name': ...
# 8   {'quantity': '1', 'unit': '(8 ounce) package',...
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13  {'quantity': '', 'unit': '', 'name': 'ground b...
# 14                                               None
# 15                                               None
# 16  {'quantity': '1', 'unit': 'cup', 'name': 'crum...
# 17                                               None
# 18                                               None
# 19                                               None
# 20  {'quantity': '1 ½', 'unit': 'pounds', 'name': ...
# 21  {'quantity': '', 'unit': '', 'name': 'cooking ...
# 22  {'quantity': '1', 'unit': 'cup', 'name': 'heav...
# 23  {'quantity': '2', 'unit': '', 'name': 'eggs, b...
# 24  {'quantity': '1', 'unit': '(8 ounce) can', 'na...
# 25  {'quantity': '1', 'unit': 'teaspoon', 'name': ...
# 26                                               None
# 27                                               None
# 28  {'quantity': '½', 'unit': 'teaspoon', 'name': ...
# 29   {'quantity': '1', 'unit': 'cup', 'name': 'milk'}
# 30  {'quantity': '6', 'unit': 'slices ', 'name': '...
# 31                                               None
# 32                                               None
# 33  {'quantity': '1', 'unit': 'pinch', 'name': 'gr...
# 34  {'quantity': '1', 'unit': 'teaspoon', 'name': ...
# 35                                               None
# 36  {'quantity': '5', 'unit': '', 'name': 'skinles...
# 37  {'quantity': '1', 'unit': '(15 ounce) can', 'n...
# 38                                               None
# 39                                               None
# 40  {'quantity': '¼', 'unit': 'cup', 'name': 'whit...
# 41                                               None
# 42                                               None
# 43                                               None
# 44  {'quantity': '2', 'unit': 'tablespoons', 'name...
# 45                                               None
# 46  {'quantity': '¼', 'unit': 'cup', 'name': 'water'}
# 47                                               None
# 48  {'quantity': '1', 'unit': 'cup', 'name': 'pank...
# 49  {'quantity': '3', 'unit': '', 'name': 'boneles...
# 50                                               None
# 51                                               None
# 52                                               None
# 53                                               None
# 54  {'quantity': '3', 'unit': '', 'name': 'whole s...
# 55  {'quantity': '¼', 'unit': 'teaspoon', 'name': ...
# 56  {'quantity': '1 ½', 'unit': 'cups', 'name': 'w...
# 57  {'quantity': '4', 'unit': 'ounces', 'name': 'u...
# 58  {'quantity': '1', 'unit': '', 'name': 'onion, ...
#
#                                                    9   \
# 0   {'quantity': '1', 'unit': 'teaspoon', 'name': ...
# 1   {'quantity': '2', 'unit': 'tablespoons', 'name...
# 2   {'quantity': '½', 'unit': 'teaspoon', 'name': ...
# 3                                                None
# 4                                                None
# 5   {'quantity': '¼', 'unit': 'cup', 'name': 'cook...
# 6                                                None
# 7   {'quantity': '½', 'unit': 'teaspoon', 'name': ...
# 8   {'quantity': '1', 'unit': 'tablespoon', 'name'...
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13  {'quantity': '1', 'unit': '(12 inch)', 'name':...
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20  {'quantity': '2', 'unit': 'tablespoons', 'name...
# 21                                               None
# 22  {'quantity': '¼', 'unit': 'teaspoon', 'name': ...
# 23  {'quantity': '2', 'unit': 'cups', 'name': 'pan...
# 24  {'quantity': '4', 'unit': 'ounces', 'name': 'c...
# 25       {'quantity': '1', 'unit': '', 'name': 'egg'}
# 26                                               None
# 27                                               None
# 28  {'quantity': '', 'unit': '', 'name': 'salt to ...
# 29  {'quantity': '3', 'unit': '', 'name': 'skinles...
# 30  {'quantity': '2', 'unit': 'sprigs', 'name': 'f...
# 31                                               None
# 32                                               None
# 33                                               None
# 34  {'quantity': '2', 'unit': 'pinches', 'name': '...
# 35                                               None
# 36                                               None
# 37  {'quantity': '½', 'unit': 'cup', 'name': 'water'}
# 38                                               None
# 39                                               None
# 40  {'quantity': '1', 'unit': '', 'name': 'skinles...
# 41                                               None
# 42                                               None
# 43                                               None
# 44  {'quantity': '3', 'unit': 'tablespoons', 'name...
# 45                                               None
# 46  {'quantity': '3', 'unit': 'tablespoons', 'name...
# 47                                               None
# 48  {'quantity': '⅓', 'unit': 'cup', 'name': 'grat...
# 49  {'quantity': '4', 'unit': '', 'name': 'long sk...
# 50                                               None
# 51                                               None
# 52                                               None
# 53                                               None
# 54  {'quantity': '1', 'unit': '(8 ounce) package',...
# 55  {'quantity': '1', 'unit': '(14 ounce) can', 'n...
# 56    {'quantity': '', 'unit': '', 'name': 'skewers'}
# 57  {'quantity': '2', 'unit': '', 'name': 'cooked ...
# 58  {'quantity': '3', 'unit': 'cups', 'name': 'bro...
#
#                                                    10  \
# 0   {'quantity': '1', 'unit': 'teaspoon', 'name': ...
# 1   {'quantity': '1', 'unit': 'head', 'name': 'bro...
# 2   {'quantity': '½', 'unit': 'teaspoon', 'name': ...
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7   {'quantity': '¼', 'unit': 'teaspoon', 'name': ...
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13  {'quantity': '4', 'unit': 'tablespoons', 'name...
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20  {'quantity': '2', 'unit': 'tablespoons', 'name...
# 21                                               None
# 22  {'quantity': '¼', 'unit': 'teaspoon', 'name': ...
# 23  {'quantity': '1', 'unit': 'pinch', 'name': 'ca...
# 24  {'quantity': '4', 'unit': '', 'name': 'green o...
# 25   {'quantity': '¼', 'unit': 'cup', 'name': 'milk'}
# 26                                               None
# 27                                               None
# 28  {'quantity': '2', 'unit': '', 'name': 'skinles...
# 29  {'quantity': '¼', 'unit': 'cup', 'name': 'hot ...
# 30                                               None
# 31                                               None
# 32                                               None
# 33                                               None
# 34  {'quantity': '¼', 'unit': 'cup', 'name': 'chop...
# 35                                               None
# 36                                               None
# 37  {'quantity': '⅓', 'unit': 'cup', 'name': 'chop...
# 38                                               None
# 39                                               None
# 40  {'quantity': '1', 'unit': 'pinch', 'name': 'dr...
# 41                                               None
# 42                                               None
# 43                                               None
# 44  {'quantity': '2', 'unit': 'tablespoons', 'name...
# 45                                               None
# 46  {'quantity': '2', 'unit': 'tablespoons', 'name...
# 47                                               None
# 48  {'quantity': '', 'unit': '', 'name': 'cooking ...
# 49  {'quantity': '1', 'unit': 'tablespoon', 'name'...
# 50                                               None
# 51                                               None
# 52                                               None
# 53                                               None
# 54  {'quantity': '1', 'unit': '(8 ounce) container...
# 55  {'quantity': '1', 'unit': 'cup', 'name': 'heav...
# 56                                               None
# 57  {'quantity': '1', 'unit': 'pinch', 'name': 'ca...
# 58                                               None
#
#                                                    11  \
# 0   {'quantity': '1', 'unit': 'tablespoon', 'name'...
# 1   {'quantity': '1', 'unit': '', 'name': 'onion, ...
# 2   {'quantity': '1', 'unit': 'teaspoon', 'name': ...
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7   {'quantity': '3', 'unit': 'tablespoons', 'name...
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13  {'quantity': '¼', 'unit': 'cup', 'name': 'thin...
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22  {'quantity': '¼', 'unit': 'teaspoon', 'name': ...
# 23  {'quantity': '2', 'unit': 'cups', 'name': 'veg...
# 24  {'quantity': '1', 'unit': 'tablespoon', 'name'...
# 25  {'quantity': '8', 'unit': '(6 ounce)', 'name':...
# 26                                               None
# 27                                               None
# 28  {'quantity': '1', 'unit': 'tablespoon', 'name'...
# 29  {'quantity': '1', 'unit': 'tablespoon', 'name'...
# 30                                               None
# 31                                               None
# 32                                               None
# 33                                               None
# 34  {'quantity': '½', 'unit': 'cup', 'name': 'shre...
# 35                                               None
# 36                                               None
# 37  {'quantity': '1', 'unit': 'clove', 'name': 'ga...
# 38                                               None
# 39                                               None
# 40  {'quantity': '', 'unit': '', 'name': 'salt and...
# 41                                               None
# 42                                               None
# 43                                               None
# 44                                               None
# 45                                               None
# 46                                               None
# 47                                               None
# 48                                               None
# 49  {'quantity': '1', 'unit': 'clove', 'name': 'ga...
# 50                                               None
# 51                                               None
# 52                                               None
# 53                                               None
# 54  {'quantity': '1', 'unit': 'cup', 'name': 'crus...
# 55  {'quantity': '1', 'unit': 'tablespoon', 'name'...
# 56                                               None
# 57  {'quantity': '', 'unit': '', 'name': 'salt and...
# 58                                               None
#
#                                                    12  \
# 0   {'quantity': '1', 'unit': '(15 ounce) can', 'n...
# 1   {'quantity': '1', 'unit': 'cup', 'name': 'slic...
# 2   {'quantity': '½', 'unit': 'teaspoon', 'name': ...
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7   {'quantity': '2', 'unit': 'tablespoons', 'name...
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13  {'quantity': '1', 'unit': 'tablespoon', 'name'...
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22  {'quantity': '⅛', 'unit': 'teaspoon', 'name': ...
# 23                                               None
# 24                                               None
# 25  {'quantity': '½', 'unit': 'cup', 'name': 'vege...
# 26                                               None
# 27                                               None
# 28  {'quantity': '1', 'unit': 'cup', 'name': 'plai...
# 29                                               None
# 30                                               None
# 31                                               None
# 32                                               None
# 33                                               None
# 34  {'quantity': '', 'unit': '', 'name': 'salt to ...
# 35                                               None
# 36                                               None
# 37  {'quantity': '1', 'unit': 'tablespoon', 'name'...
# 38                                               None
# 39                                               None
# 40  {'quantity': '½', 'unit': 'cup', 'name': 'heav...
# 41                                               None
# 42                                               None
# 43                                               None
# 44                                               None
# 45                                               None
# 46                                               None
# 47                                               None
# 48                                               None
# 49  {'quantity': '1', 'unit': '', 'name': 'jalapen...
# 50                                               None
# 51                                               None
# 52                                               None
# 53                                               None
# 54                                               None
# 55  {'quantity': '2', 'unit': 'teaspoons', 'name':...
# 56                                               None
# 57                                               None
# 58                                               None
#
#                                                    13  \
# 0   {'quantity': '1', 'unit': 'cup', 'name': 'plai...
# 1   {'quantity': '1', 'unit': '(8 ounce) can', 'na...
# 2   {'quantity': '2', 'unit': 'teaspoons', 'name':...
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13  {'quantity': '1', 'unit': 'small', 'name': 'ja...
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22  {'quantity': '⅛', 'unit': 'teaspoon', 'name': ...
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28  {'quantity': '¾', 'unit': 'cup', 'name': 'coco...
# 29                                               None
# 30                                               None
# 31                                               None
# 32                                               None
# 33                                               None
# 34                                               None
# 35                                               None
# 36                                               None
# 37  {'quantity': '½', 'unit': 'teaspoon', 'name': ...
# 38                                               None
# 39                                               None
# 40                                               None
# 41                                               None
# 42                                               None
# 43                                               None
# 44                                               None
# 45                                               None
# 46                                               None
# 47                                               None
# 48                                               None
# 49  {'quantity': '2', 'unit': 'teaspoons', 'name':...
# 50                                               None
# 51                                               None
# 52                                               None
# 53                                               None
# 54                                               None
# 55  {'quantity': '1', 'unit': 'tablespoon', 'name'...
# 56                                               None
# 57                                               None
# 58                                               None
#
#                                                    14  \
# ...
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28  {'quantity': '½', 'unit': 'teaspoon', 'name': ...
# 29                                               None
# 30                                               None
# 31                                               None
# 32                                               None
# 33                                               None
# 34                                               None
# 35                                               None
# 36                                               None
# 37  {'quantity': '1', 'unit': '(12 ounce) jar', 'n...
# 38                                               None
# 39                                               None
# 40                                               None
# 41                                               None
# 42                                               None
# 43                                               None
# 44                                               None
# 45                                               None
# 46                                               None
# 47                                               None
# 48                                               None
# 49  {'quantity': '1', 'unit': 'cup', 'name': 'heav...
# 50                                               None
# 51                                               None
# 52                                               None
# 53                                               None
# 54                                               None
# 55  {'quantity': '½', 'unit': 'teaspoon', 'name': ...
# 56                                               None
# 57                                               None
# 58                                               None
#
#                                                    16  \
# 0   {'quantity': '½', 'unit': 'cup', 'name': 'water'}
# 1                                                None
# 2   {'quantity': '2 ½', 'unit': 'cups', 'name': 'c...
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
# 29                                               None
# 30                                               None
# 31                                               None
# 32                                               None
# 33                                               None
# 34                                               None
# 35                                               None
# 36                                               None
# 37                                               None
# 38                                               None
# 39                                               None
# 40                                               None
# 41                                               None
# 42                                               None
# 43                                               None
# 44                                               None
# 45                                               None
# 46                                               None
# 47                                               None
# 48                                               None
# 49  {'quantity': '¼', 'unit': 'cup', 'name': 'chop...
# 50                                               None
# 51                                               None
# 52                                               None
# 53                                               None
# 54                                               None
# 55                                               None
# 56                                               None
# 57                                               None
# 58                                               None
#
#                                                    17  \
# 0   {'quantity': '1', 'unit': 'teaspoon', 'name': ...
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
# 29                                               None
# 30                                               None
# 31                                               None
# 32                                               None
# 33                                               None
# 34                                               None
# 35                                               None
# 36                                               None
# 37                                               None
# 38                                               None
# 39                                               None
# 40                                               None
# 41                                               None
# 42                                               None
# 43                                               None
# 44                                               None
# 45                                               None
# 46                                               None
# 47                                               None
# 48                                               None
# 49                                               None
# 50                                               None
# 51                                               None
# 52                                               None
# 53                                               None
# 54                                               None
# 55                                               None
# 56                                               None
# 57                                               None
# 58                                               None
#
#                                                    18  \
# 0   {'quantity': '1', 'unit': 'tablespoon', 'name'...
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
# 29                                               None
# 30                                               None
# 31                                               None
# 32                                               None
# 33                                               None
# 34                                               None
# 35                                               None
# 36                                               None
# 37                                               None
# 38                                               None
# 39                                               None
# 40                                               None
# 41                                               None
# 42                                               None
# 43                                               None
# 44                                               None
# 45                                               None
# 46                                               None
# 47                                               None
# 48                                               None
# 49                                               None
# 50                                               None
# 51                                               None
# 52                                               None
# 53                                               None
# 54                                               None
# 55                                               None
# 56                                               None
# 57                                               None
# 58                                               None
#
#                                                    19
# 0   {'quantity': '1', 'unit': 'tablespoon', 'name'...
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
# 29                                               None
# 30                                               None
# 31                                               None
# 32                                               None
# 33                                               None
# 34                                               None
# 35                                               None
# 36                                               None
# 37                                               None
# 38                                               None
# 39                                               None
# 40                                               None
# 41                                               None
# 42                                               None
# 43                                               None
# 44                                               None
# 45                                               None
# 46                                               None
# 47                                               None
# 48                                               None
# 49                                               None
# 50                                               None
# 51                                               None
# 52                                               None
# 53                                               None
# 54                                               None
# 55                                               None
# 56                                               None
# 57                                               None
# 58                                               None

# %%
Quantity=[]
UNIT_1=[]
NAME_1=[]

def frame(value,col):
    for i in range(0,20):
        for j in range(0,59):
            if dict_df.iloc[j,i] is None:
                col.append(np.nan)
            else:
                col.append(dict_df.iloc[j,i][value])

# %%
frame("quantity",Quantity)

# %%
frame("unit",UNIT_1)

# %%
frame("name",NAME_1)

# %%
final_list=list(zip(Quantity, UNIT_1,NAME_1))

# %%
final_list
# Out:
# [('2', 'pounds', 'skinless, boneless chicken breast halves'),
#  ('4', 'cups', 'water'),
#  ('2', 'tablespoons', 'peanut oil, divided'),
#  ('4',
#   '',
#   'skinless, boneless chicken breast halves - pounded to 1/2 inch thickness'),
#  ('4', '(5 ounce)', 'skinless, boneless chicken breast halves'),
#  ('¼', 'cup', 'all-purpose flour for coating'),
#  ('2', 'tablespoons', 'olive oil'),
#  ('1 ½', 'cups', 'water'),
#  ('1', 'pound', 'skinless, boneless chicken breast, diced'),
#  ('', '', 'nonstick cooking spray'),
#  ('4', '', 'skinless, boneless chicken breast halves'),
#  ('2', 'tablespoons', 'olive oil'),
#  ('25',
#   'ounces',
#   'frozen cooked, breaded crispy chicken strips (such as Tyson®)'),
#  ('½', 'cup', 'rice vinegar'),
#  ('1', '(16 ounce) bottle', 'Italian-style salad dressing'),
#  ('⅓', 'cup', 'honey'),
#  ('4', '', 'skinless, boneless chicken breast halves'),
#  ('1', 'pound', 'skinless, boneless chicken breast halves'),
#  ('3', '', 'skinless, boneless chicken breasts'),
#  ('1', '(16 ounce) package', 'bow tie pasta'),
#  ('1', 'cup', 'butter, divided'),
#  ('½', 'teaspoon', 'paprika'),
#  ('4', 'ounces', 'linguine pasta'),
#  ('2', 'cloves', 'garlic, minced'),
#  ('2', 'tablespoons', 'cornstarch, dissolved in 2 tablespoons water'),
#  ('2', 'cups', 'flour'),
#  ('4', '', 'skinless, boneless chicken breast halves'),
#  ('¼', 'cup', 'honey'),
#  ('3', 'tablespoons', 'olive oil'),
#  ('', '', 'oil for deep frying'),
#  ('1', 'large', 'egg, beaten'),
#  ('1', 'cup', 'part skim milk ricotta cheese '),
#  ('1', 'tablespoon', 'olive oil, or as desired'),
#  ('1', 'teaspoon', 'unsalted butter, or as needed'),
#  ('1', 'tablespoon', 'olive oil'),
#  ('1', 'pound', 'boneless skinless chicken breasts'),
#  ('¼', 'cup', 'red wine vinegar'),
#  ('1', 'tablespoon', 'olive oil, or as needed'),
#  ('4', '', 'skinless, boneless chicken breast halves'),
#  ('¼', 'cup', 'butter, melted'),
#  ('½', 'cup', 'chopped onion'),
#  ('¼', 'cup', 'soy sauce'),
#  ('¼', 'cup', 'olive oil'),
#  ('4', '', 'skinless, boneless chicken breast halves'),
#  ('3',
#   'large',
#   'skinless, boneless chicken breast halves - cut into 1/2-inch medallions'),
#  ('6', '', 'frozen skinless, boneless chicken breast halves'),
#  ('4', '', 'skinless, boneless chicken breast halves'),
#  ('½', 'cup', "Hellmann's® or Best Foods® Real Mayonnaise"),
#  ('2', '', 'boneless, skinless chicken breasts'),
#  ('1', 'cup', 'yogurt'),
#  ('', '', 'cooking spray'),
#  ('½', 'cup', 'ketchup'),
#  ('4', '', 'skinless, boneless chicken breast halves'),
#  ('½', 'cup', 'vegetable oil'),
#  ('2', '(10 ounce) cans', 'diced tomatoes with green chiles, undrained'),
#  ('2', 'tablespoons', 'ghee (clarified butter)'),
#  ('½', 'cup', 'teriyaki sauce'),
#  ('1', 'tablespoon', 'butter'),
#  ('⅔', 'cup', 'soy sauce'),
#  ('2', 'teaspoons', 'salt'),
#  ('2', 'cups', 'white rice'),
#  ('1', 'tablespoon', 'Cajun seasoning'),
#  ('', '', 'salt and pepper to taste'),
#  ('2', 'tablespoons', 'olive oil'),
#  ('½', 'teaspoon', 'salt'),
#  ('1', 'clove', 'garlic, minced'),
#  ('⅓', 'cup', 'rice vinegar'),
#  ('1', '(1.27 ounce) packet', 'fajita seasoning'),
#  ('4', '', 'skinless, boneless chicken breast halves'),
#  ('2', 'tablespoons', 'butter'),
#  ('1', 'tablespoon', 'ground paprika'),
#  (nan, nan, nan),
#  ('¼', 'cup', 'white sugar'),
#  ('6', '', 'skinless, boneless chicken breast halves'),
#  ('⅓', 'cup', 'soy sauce'),
#  ('6', 'ounces', 'egg noodles'),
#  ('2', 'teaspoons', 'vegetable oil'),
#  ('1', 'cup', 'Italian seasoned bread crumbs'),
#  ('1', 'teaspoon', 'olive oil'),
#  ('1', '', 'onion, minced'),
#  ('¼', 'teaspoon', 'cayenne pepper'),
#  ('2', '', 'skinless, boneless chicken breast halves'),
#  ('1', 'pinch', 'salt'),
#  ('2', 'tablespoons', 'white wine, divided'),
#  ('2', 'tablespoons', 'salt'),
#  ('1', 'sleeve', 'buttery round crackers (such as Ritz®), crushed'),
#  ('2', 'tablespoons', 'soy sauce'),
#  ('1', 'small', 'onion, chopped'),
#  ('1', 'cup', 'unbleached all-purpose flour'),
#  ('1 ½', 'medium', 'lemons, juiced, divided'),
#  ('¾', 'cup', 'finely chopped walnuts'),
#  ('6', '', 'chicken breasts, cut in half lengthwise (butterflied)'),
#  ('2', '', 'skinless, boneless chicken breasts, cubed'),
#  ('3', '', 'skinless, boneless chicken breast halves'),
#  ('1', '', 'egg'),
#  ('¼', 'cup', 'reduced-sodium soy sauce'),
#  ('4', '', 'skinless, boneless chicken breast halves'),
#  ('1', '(18 ounce) bottle', "barbeque sauce (such as Sweet Baby Ray's®)"),
#  ('1', 'teaspoon', 'salt'),
#  ('2', 'stalks', 'celery, chopped'),
#  ('2', 'tablespoons', 'honey'),
#  ('2', 'cloves', 'garlic, minced'),
#  ('1', '(17.5 fluid ounce) bottle', 'Buffalo wing sauce, divided'),
#  ('', '', 'salt and pepper to taste'),
#  ('1', '(12 ounce) bottle', 'barbeque sauce'),
#  ('', '', 'cayenne pepper to taste'),
#  ('¼', 'cup', 'grated Parmesan cheese'),
#  ('', '', 'salt and ground black pepper to taste'),
#  ('1', 'tablespoon', 'lemon juice'),
#  ('6', '', 'skinless, boneless chicken breast halves'),
#  ('2', 'tablespoons', 'soy sauce'),
#  ('4', 'teaspoons', 'taco seasoning mix'),
#  ('2', 'tablespoons', 'chili powder'),
#  ('1', '(16 ounce) can', 'chili beans'),
#  ('1', '', 'onion, finely chopped'),
#  ('½', 'cup', 'honey'),
#  ('½', 'cup', 'diced carrot'),
#  ('¼', 'cup', 'brown sugar'),
#  ('½', 'cup', 'cooking oil'),
#  ('⅔', 'cup', 'soy sauce'),
#  ('10', 'ounces', 'andouille sausage, sliced into rounds'),
#  ('2', 'tablespoons', 'all-purpose flour'),
#  ('½', 'teaspoon', 'coarse sea salt, or to taste'),
#  ('¼', 'teaspoon', 'ground black pepper'),
#  ('1', 'cup', 'dry bread crumbs'),
#  ('¼', 'cup', 'lemon juice'),
#  ('1', 'tablespoon', 'vegetable oil'),
#  ('¼', 'teaspoon', 'salt'),
#  ('2', '(10.5 ounce) cans', 'condensed cream of chicken soup'),
#  ('2', 'teaspoons', 'dried oregano'),
#  (nan, nan, nan),
#  ('¼', 'cup', 'water'),
#  (nan, nan, nan),
#  ('¼', 'cup', 'vegetable oil'),
#  ('1', '(10.5 ounce) can', 'condensed cream of mushroom soup'),
#  ('1', 'tablespoon', 'minced onion'),
#  ('½', 'cup', 'grated Parmesan cheese'),
#  ('2', 'cloves', 'garlic, minced'),
#  ('1', 'tablespoon', 'minced garlic'),
#  ('¼', 'teaspoon', 'ground cumin'),
#  ('2', 'teaspoons', 'Cajun seasoning'),
#  ('2', 'tablespoons', 'chopped fresh flat-leaf parsley'),
#  ('2', 'tablespoons', 'soy sauce, divided'),
#  ('2', 'tablespoons', 'ground black pepper'),
#  ('½', 'cup', 'butter, melted'),
#  ('⅛', 'teaspoon', 'red pepper flakes'),
#  ('2', 'cloves', 'garlic, minced'),
#  ('2', 'teaspoons', 'salt'),
#  ('1', 'cup', 'all-purpose flour'),
#  ('½', 'cup', 'grated Parmesan cheese'),
#  ('', '', 'salt and ground black pepper to taste'),
#  ('3', 'cups', 'finely chopped broccoli'),
#  ('1', 'large', 'onion, chopped'),
#  ('1', 'cup', 'panko crumbs'),
#  ('¼', 'cup', 'olive oil'),
#  ('1', '', 'onion, chopped'),
#  ('¼', 'cup', 'distilled white vinegar'),
#  ('4', '', 'skinless, boneless chicken breast halves'),
#  ('1', '', 'carrot, diced'),
#  ('4', 'teaspoons', 'sesame oil'),
#  ('2', 'tablespoons', 'lemon juice'),
#  ('½', '(1 ounce) package', 'dry ranch salad dressing mix'),
#  ('½', 'cup', 'all-purpose flour'),
#  ('½', 'cup', 'Italian salad dressing'),
#  ('', '', 'salt and ground black pepper to taste'),
#  ('4', '(5 ounce)', 'boneless, skinless chicken breast halves'),
#  ('1', 'tablespoon', 'Dijon mustard'),
#  ('4', 'teaspoons', 'ground cumin, divided'),
#  ('', '', 'salt and pepper to taste'),
#  ('1', 'tablespoon', 'brown sugar'),
#  ('1', 'cup', 'salsa'),
#  ('2', 'tablespoons', 'lime juice'),
#  ('1', '(15 ounce) can', 'black beans'),
#  ('4', 'cloves', 'garlic, minced'),
#  ('½', 'teaspoon', 'garlic powder'),
#  ('½', 'cup', 'diced onion'),
#  ('½', 'teaspoon', 'ground ginger'),
#  ('1 ½', 'cups', 'chopped onion'),
#  ('¼', 'cup', 'brown sugar'),
#  ('1', 'pound', 'boneless skinless chicken breasts, cut into 1 inch pieces'),
#  ('1', '', 'egg, beaten'),
#  ('1',
#   'pinch',
#   "Creole seasoning (such as Tony Chachere's®), or more to taste"),
#  ('½', 'teaspoon', 'dried oregano'),
#  ('⅔', 'cup', 'grated Parmesan cheese'),
#  ('2 ½', 'tablespoons', 'soy sauce'),
#  ('2', '', 'green bell peppers, chopped'),
#  ('⅛', 'teaspoon', 'ground black pepper'),
#  ('1', 'medium', 'onion, finely diced'),
#  ('', '', 'salt and ground black pepper to taste'),
#  (nan, nan, nan),
#  ('¼', 'cup', 'matchstick-cut carrots'),
#  (nan, nan, nan),
#  ('¼', 'teaspoon', 'ground black pepper'),
#  ('1', '(10.5 ounce) can', 'condensed cream of chicken soup'),
#  ('¼', 'cup', 'tomato sauce'),
#  ('1', 'tablespoon', 'dried basil'),
#  ('2', '', 'skinless, boneless chicken breasts, cut into bite-sized pieces'),
#  ('1', '(15 ounce) can', 'tomato sauce'),
#  ('¼', 'teaspoon', 'dried thyme'),
#  ('2', 'tablespoons', 'butter'),
#  ('6', 'tablespoons', 'unsalted butter'),
#  ('2', 'tablespoons', 'sesame oil, divided'),
#  ('1', 'tablespoon', 'dried tarragon'),
#  ('1', 'teaspoon', 'poppy seeds, or more if desired'),
#  ('1 ½', 'tablespoons', 'olive oil'),
#  ('3', 'tablespoons', 'curry powder'),
#  ('½', 'teaspoon', 'ground black pepper'),
#  ('1', 'pinch', 'garlic powder'),
#  ('½', 'cup', 'dry bread crumbs'),
#  ('¾', 'cup', 'all-purpose flour'),
#  ('2', '(10.5 ounce) cans', 'condensed cream of chicken soup'),
#  ('2', 'cloves', 'garlic, minced'),
#  ('½', 'teaspoon', 'Spice Islands® Garlic Powder'),
#  ('1 ½', 'teaspoons', 'dried parsley flakes'),
#  ('1 ¾', 'cups', 'shredded Cheddar cheese, divided'),
#  ('¼', 'cup', 'brown sugar'),
#  (nan, nan, nan),
#  ('¼', 'cup', 'butter'),
#  ('2', 'cloves', 'garlic, crushed'),
#  ('1', 'teaspoon', 'dried oregano'),
#  ('2', 'tablespoons', 'butter'),
#  ('2', 'tablespoons', 'vegetable oil, or as needed'),
#  ('¼', 'cup', 'brown sugar'),
#  ('', '', 'all-purpose flour for dredging'),
#  ('4', 'teaspoons', 'Italian seasoned dry bread crumbs'),
#  ('4', 'slices', 'deli Swiss cheese'),
#  ('1', 'teaspoon', 'ground cinnamon'),
#  ('½', 'cup', 'honey'),
#  ('1', 'tablespoon', 'sherry'),
#  ('1', 'cup', 'shredded Cheddar cheese'),
#  ('2', 'tablespoons', 'honey'),
#  ('1', '(15 ounce) can', 'whole kernel corn, drained'),
#  ('1', 'tablespoon', 'ground cumin'),
#  ('½', 'pinch', 'ground ginger'),
#  ('½', 'cup', 'diced celery'),
#  ('1', 'pinch', 'red pepper flakes, or to taste'),
#  ('1', 'tablespoon', 'minced garlic'),
#  ('1', 'tablespoon', 'cornstarch'),
#  ('1', '', 'onion, diced'),
#  ('1', 'cup', 'panko bread crumbs'),
#  ('1', 'tablespoon', 'chicken broth, or more to taste'),
#  ('4',
#   'medium',
#   'skinless, boneless chicken breast halves - pounded 1/4 inch thick'),
#  ('1', 'teaspoon', 'dried basil leaves'),
#  ('2', 'tablespoons', 'orange juice'),
#  ('2', '', 'red bell peppers, chopped'),
#  ('6', 'slices', 'Swiss cheese'),
#  ('1', '(10 ounce) package', 'refrigerated biscuit dough'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('¼', 'cup', 'peeled and matchstick-cut daikon radish'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('1', 'cup', 'sour cream'),
#  ('1', 'pinch', 'ground cumin'),
#  ('1', 'teaspoon', 'dried thyme'),
#  ('1', 'pinch', 'crushed red pepper flakes, or to taste'),
#  ('3', 'cups', 'heavy cream'),
#  ('⅛', 'teaspoon', 'onion powder'),
#  ('1', '', 'red bell pepper, sliced'),
#  ('4',
#   '(8 ounce)',
#   'skinless, boneless chicken breast halves, pounded to 1/4-inch thickness'),
#  ('1', 'pound', 'skinless, boneless chicken breast halves - cut into chunks'),
#  ('1', 'tablespoon', 'ground ginger'),
#  ('1', '(10.75 ounce) can ', 'condensed cream of chicken soup'),
#  ('2',
#   '',
#   'skinless, boneless chicken breast halves, cut into bite-size pieces'),
#  ('1', 'teaspoon', 'ground cinnamon'),
#  ('½', 'teaspoon', 'cayenne pepper'),
#  ('1', 'pinch', 'paprika'),
#  ('1', 'teaspoon', 'dried oregano'),
#  ('1', 'tablespoon', 'ground paprika'),
#  ('1', 'cup', 'shredded Cheddar cheese'),
#  ('5 ¼', 'cups', 'chicken broth'),
#  ('½', 'teaspoon', 'Spice Islands® Onion Powder'),
#  ('½', 'teaspoon', 'dried basil'),
#  ('½', 'pint', 'sour cream'),
#  ('1', 'teaspoon', 'garlic powder'),
#  (nan, nan, nan),
#  ('1 ½', 'tablespoons', 'all-purpose flour'),
#  ('3', 'slices', 'fresh ginger root'),
#  ('½', 'teaspoon', 'salt'),
#  ('6', '', 'hoagie rolls, split lengthwise'),
#  ('1', 'clove', 'garlic, minced'),
#  ('2', 'tablespoons', 'Worcestershire sauce'),
#  ('2', 'tablespoons', 'olive oil'),
#  (nan, nan, nan),
#  ('4', 'slices', 'deli ham'),
#  ('2', 'teaspoons', 'cayenne pepper'),
#  ('½', 'cup', 'prepared mustard'),
#  ('2', 'teaspoons', 'Worcestershire sauce'),
#  ('2', 'tablespoons', 'sour cream (Optional)'),
#  ('2', 'tablespoons', 'garlic powder'),
#  ('1', '(12 fluid ounce) can or bottle', 'beer'),
#  ('1', 'teaspoon', 'salt, or more to taste (Optional)'),
#  ('1 ½',
#   'pounds',
#   'skinless, boneless chicken breast halves - cut into cubes'),
#  ('¼', 'teaspoon', 'fresh thyme leaves'),
#  ('2', 'tablespoons', 'water'),
#  ('1 ½', 'teaspoons', 'minced fresh ginger root'),
#  ('1', 'tablespoon', 'minced fresh ginger'),
#  ('1', 'small', 'green bell pepper, diced'),
#  ('1', 'cup', 'oil for frying, or as needed'),
#  (nan, nan, nan),
#  ('4', 'tablespoons', 'butter'),
#  ('¼', 'teaspoon', 'ground black pepper'),
#  ('1', 'cup', 'packed brown sugar'),
#  ('1', '', 'onion, chopped'),
#  ('4', 'slices', 'cooked ham'),
#  ('2', 'cups', 'water, or as needed to cover'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('¼', 'cup', 'thinly sliced white onion'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('', '', 'salt to taste'),
#  ('1', 'pinch', 'chili powder'),
#  ('1', 'teaspoon', 'salt'),
#  ('½', 'cup', 'pesto sauce'),
#  ('2', 'teaspoons', 'salt'),
#  ('⅛', 'teaspoon', 'ground white pepper'),
#  ('1', '', 'green bell pepper, sliced'),
#  ('', '', 'salt and pepper to taste'),
#  ('1', 'ounce', 'hot chile paste'),
#  ('1', 'tablespoon', 'dry mustard powder'),
#  ('1', '(8 ounce) container', 'sour cream'),
#  (nan, nan, nan),
#  ('1', 'teaspoon', 'paprika'),
#  ('½', 'teaspoon', 'paprika'),
#  ('6', '', 'skinless, boneless chicken breast halves'),
#  ('6', '', 'boneless chicken breast halves, with skin'),
#  ('2', 'large', 'eggs, beaten'),
#  ('1', 'cup', 'shredded Parmesan cheese, divided'),
#  ('3',
#   '(15 ounce) cans',
#   'cannellini (white kidney) beans, rinsed and drained'),
#  ('½', 'teaspoon', 'Spice Islands® Fine Grind Sea Salt'),
#  ('½', 'teaspoon', 'dried oregano'),
#  ('1', 'tablespoon', 'dried parsley'),
#  ('½', 'teaspoon', 'red pepper flakes'),
#  (nan, nan, nan),
#  ('1 ½', 'teaspoons', 'curry powder'),
#  ('4', '', 'skinless, boneless chicken breast halves'),
#  ('1 ½',
#   'pounds',
#   'skinless, boneless chicken breast halves - cut into bite-sized pieces'),
#  (nan, nan, nan),
#  ('1', 'cup', 'low sodium chicken broth'),
#  (nan, nan, nan),
#  ('1', 'tablespoon', 'capers, drained'),
#  (nan, nan, nan),
#  ('', '', '2 toothpicks'),
#  ('2', 'teaspoons', 'freshly ground black pepper'),
#  ('1', 'teaspoon', 'dried basil'),
#  ('1', 'teaspoon', 'minced garlic'),
#  (nan, nan, nan),
#  ('½', 'teaspoon', 'paprika'),
#  ('1', '(8 ounce) can', 'tomato sauce'),
#  ('1', 'teaspoon', 'ground ginger'),
#  ('1', 'pound', 'beef sirloin, cut into 1 inch cubes'),
#  ('1', 'pinch', 'salt'),
#  ('2', 'tablespoons', 'cornstarch'),
#  ('1', 'tablespoon', 'curry powder'),
#  ('1', 'tablespoon', 'minced garlic'),
#  ('2', 'stalks', 'celery, diced'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('4', 'tablespoons', 'olive oil'),
#  ('6', '', 'skinless, boneless chicken breast halves'),
#  ('2', 'tablespoons', 'chopped green onion'),
#  ('10', '(10 inch)', 'flour tortillas'),
#  ('½', 'cup', 'seasoned bread crumbs'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('1', '', 'skinless, boneless chicken breast half'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('', '', 'ground black pepper to taste'),
#  (nan, nan, nan),
#  ('½', 'cup', 'butter, melted'),
#  ('⅓', 'cup', 'oil-packed sun-dried tomatoes, drained and cut into strips'),
#  ('1', 'teaspoon', 'cayenne pepper'),
#  ('⅛', 'teaspoon', 'salt'),
#  ('4', '', 'fresh mushrooms, sliced'),
#  ('1', 'cup', 'all-purpose flour'),
#  ('2', 'teaspoons', 'brown sugar'),
#  ('1', 'tablespoon', 'dried thyme leaves'),
#  ('2', 'cups', 'shredded Cheddar cheese'),
#  (nan, nan, nan),
#  ('1', '', 'bay leaf'),
#  ('¼', 'teaspoon', 'garlic powder'),
#  ('2', 'tablespoons', 'butter'),
#  ('2', 'tablespoons', 'vegetable oil'),
#  ('2', 'cups', 'seasoned bread crumbs'),
#  ('½', 'cup', 'shredded mozzarella cheese'),
#  ('2', '(4 ounce) cans', 'chopped green chiles'),
#  ('¼', 'teaspoon', 'Spice Islands® Fine Grind Black Pepper'),
#  ('¼', 'teaspoon', 'garlic powder'),
#  ('½', 'teaspoon', 'dried oregano'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('4', 'cups', 'chicken broth'),
#  (nan, nan, nan),
#  ('6', '', 'wooden skewers, or as needed'),
#  (nan, nan, nan),
#  ('½', '', 'lemon, thinly sliced'),
#  (nan, nan, nan),
#  ('½', 'cup', 'white wine'),
#  (nan, nan, nan),
#  ('¼', 'cup', 'all-purpose flour'),
#  ('1', 'tablespoon', 'minced fresh ginger'),
#  ('1', 'teaspoon', 'paprika'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('½', 'teaspoon', 'ground black pepper'),
#  ('1', '', 'onion, chopped'),
#  ('1', 'teaspoon', 'cayenne pepper'),
#  ('2', '', 'red bell peppers, cut into 2 inch pieces'),
#  ('2', 'tablespoons', 'melted chicken fat'),
#  ('2', 'teaspoons', 'vegetable oil, or to taste'),
#  ('1', 'teaspoon', 'ground cumin'),
#  ('¼', 'teaspoon', 'red pepper flakes'),
#  ('3', 'cloves', 'garlic, minced'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('1', 'cup', 'sliced mushrooms'),
#  (nan, nan, nan),
#  ('1', 'tablespoon', 'grated orange zest'),
#  ('1', '(8 ounce) package', 'shredded Cheddar cheese'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('1', 'pinch', 'garlic salt, or to taste'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('½', 'cup', 'butter'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('1', 'teaspoon', 'garam masala'),
#  ('2', '', 'skinless, boneless chicken breast halves'),
#  ('1', '', 'green onion, chopped'),
#  ('2', 'teaspoons', 'salt'),
#  ('1', 'teaspoon', 'distilled white vinegar'),
#  ('1', 'teaspoon', 'garlic powder'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('½', 'teaspoon', 'grated fresh ginger root'),
#  ('1', '', 'egg'),
#  ('1', '(14.5 ounce) can', 'chicken broth'),
#  (nan, nan, nan),
#  ('1', 'large', 'lemon, zested'),
#  ('½', 'cup', 'sour cream'),
#  ('1', 'tablespoon', 'dried oregano'),
#  ('¼', 'cup', 'Mazola® Corn Oil'),
#  ('¼', 'teaspoon', 'ground black pepper'),
#  ('½', 'teaspoon', 'ground black pepper'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('½', '', 'apple, cored and chopped'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('¼', 'cup', 'fresh lemon juice'),
#  (nan, nan, nan),
#  ('¼', 'cup', 'fresh lemon juice'),
#  (nan, nan, nan),
#  ('1', '', 'egg, beaten'),
#  ('2', 'teaspoons', 'salt, divided, or more to taste'),
#  ('½', 'teaspoon', 'dried parsley'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('3', 'pounds', 'skinless, boneless chicken breasts, cut into strips'),
#  ('1', '(1.25 ounce) package', 'taco seasoning'),
#  ('½', 'teaspoon', 'ground cinnamon'),
#  ('1', 'large', 'sweet onion, peeled and cut into wedges'),
#  ('2', 'quarts', 'roasted chicken broth (see footnote for recipe link)'),
#  ('3', '', 'skinless, boneless chicken breast halves, cut into chunks'),
#  ('1', 'teaspoon', 'ground turmeric'),
#  ('3', '', 'skinless, boneless chicken breast halves, thinly sliced'),
#  ('1', '(16 ounce) can', 'crushed Italian tomatoes'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('½', 'cup', 'Marsala wine'),
#  (nan, nan, nan),
#  ('½', 'teaspoon', 'minced fresh ginger root'),
#  ('1', '(8 ounce) package', 'shredded Monterey Jack cheese'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('', '', 'ground black pepper to taste'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('1', 'cup', 'crumbled buttery round crackers'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('1 ½',
#   'pounds',
#   'skinless, boneless chicken breast, cut into bite-sized chunks'),
#  ('', '', 'cooking spray'),
#  ('1', 'cup', 'heavy cream'),
#  ('2', '', 'eggs, beaten'),
#  ('1', '(8 ounce) can', 'water chestnuts'),
#  ('1', 'teaspoon', 'dried oregano'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('½', 'teaspoon', 'white sugar'),
#  ('1', 'cup', 'milk'),
#  ('6', 'slices ', 'lemon, for garnish'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('1', 'pinch', 'ground black pepper to taste'),
#  ('1', 'teaspoon', 'ground cumin'),
#  (nan, nan, nan),
#  ('5', '', 'skinless, boneless chicken breasts, thinly sliced'),
#  ('1', '(15 ounce) can', 'tomato sauce'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('¼', 'cup', 'white rice'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('2', 'tablespoons', 'capers, drained and rinsed'),
#  (nan, nan, nan),
#  ('¼', 'cup', 'water'),
#  (nan, nan, nan),
#  ('1', 'cup', 'panko bread crumbs'),
#  ('3', '', 'boneless skinless chicken breasts, cut into bite-size pieces'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('3', '', 'whole skinless, boneless chicken breasts'),
#  ('¼', 'teaspoon', 'ground turmeric'),
#  ('1 ½', 'cups', 'whole fresh mushrooms'),
#  ('4', 'ounces', 'uncooked wide egg noodles'),
#  ('1', '', 'onion, sliced'),
#  ('1', 'teaspoon', 'ground coriander'),
#  ('2', 'tablespoons', 'sesame oil, divided'),
#  ('½', 'teaspoon', 'red pepper flakes'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('¼', 'cup', 'cooking sherry'),
#  (nan, nan, nan),
#  ('½', 'teaspoon', 'minced garlic'),
#  ('1', 'tablespoon', 'bacon bits'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('1', '(12 inch)', 'French baguette'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('2', 'tablespoons', 'vegetable oil'),
#  (nan, nan, nan),
#  ('¼', 'teaspoon', 'dried basil'),
#  ('2', 'cups', 'panko bread crumbs'),
#  ('4', 'ounces', 'chopped peanuts'),
#  ('1', '', 'egg'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('', '', 'salt to taste'),
#  ('3', '', 'skinless, boneless chicken breasts, cut into 1/2-inch strips'),
#  ('2', 'sprigs', 'fresh parsley, for garnish'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('2', 'pinches', 'cayenne pepper, or to taste'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('½', 'cup', 'water'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('1', '', 'skinless, boneless chicken breast half - cut into cubes'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('3', 'tablespoons', 'butter'),
#  (nan, nan, nan),
#  ('3', 'tablespoons', 'cold unsalted butter, cut in 1/4-inch slices'),
#  (nan, nan, nan),
#  ('⅓', 'cup', 'grated Parmesan cheese'),
#  ('4', '', 'long skewers'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('1', '(8 ounce) package', 'shredded Cheddar cheese (Optional)'),
#  ('1', '(14 ounce) can', 'tomato sauce'),
#  ('', '', 'skewers'),
#  ('2', '', 'cooked boneless chicken breast halves, cubed'),
#  ('3', 'cups', 'broccoli florets'),
#  ('1', 'teaspoon', 'cayenne pepper'),
#  ('1', 'head', 'broccoli, broken into florets'),
#  ('½', 'teaspoon', 'ground black pepper'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('¼', 'teaspoon', 'red pepper flakes'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('4', 'tablespoons', 'mayonnaise'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('2', 'tablespoons', 'tandoori masala'),
#  (nan, nan, nan),
#  ('¼', 'teaspoon', 'lemon pepper'),
#  ('1', 'pinch', 'cayenne pepper'),
#  ('4', '', 'green onions, chopped'),
#  ('¼', 'cup', 'milk'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('2',
#   '',
#   'skinless, boneless chicken breast halves - cut into bite-size pieces'),
#  ('¼', 'cup', 'hot pepper sauce'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('¼', 'cup', 'chopped fresh cilantro, or to taste'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('⅓', 'cup', 'chopped green bell pepper'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('1', 'pinch', 'dried thyme'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('2', 'tablespoons', 'minced Italian (flat-leaf) parsley'),
#  (nan, nan, nan),
#  ('2', 'tablespoons', 'chopped fresh Italian parsley'),
#  (nan, nan, nan),
#  ('', '', 'cooking spray'),
#  ('1', 'tablespoon', 'butter'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('1', '(8 ounce) container', 'sour cream'),
#  ('1', 'cup', 'heavy whipping cream'),
#  (nan, nan, nan),
#  ('1', 'pinch', 'cayenne pepper (Optional)'),
#  (nan, nan, nan),
#  ('1', 'tablespoon', 'water'),
#  ('1', '', 'onion, cut into large chunks'),
#  ('1', 'teaspoon', 'salt'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('3', 'tablespoons', 'cornstarch'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('¼', 'cup', 'thinly sliced cucumber '),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('¼', 'teaspoon', 'salt'),
#  ('2', 'cups', 'vegetable oil for frying, or as needed'),
#  ('1', 'tablespoon', 'chopped garlic'),
#  ('8', '(6 ounce)', 'skinless, boneless chicken breast halves'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('1', 'tablespoon', 'tomato paste'),
#  ('1', 'tablespoon', 'butter'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('½', 'cup', 'shredded Monterey Jack cheese, or to taste'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('1', 'clove', 'garlic, minced'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('', '', 'salt and ground black pepper to taste'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('1', 'clove', 'garlic, minced'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('1', 'cup', 'crushed tortilla chips'),
#  ('1', 'tablespoon', 'white sugar, or more to taste (Optional)'),
#  (nan, nan, nan),
#  ('', '', 'salt and ground black pepper to taste'),
#  (nan, nan, nan),
#  ('1', '(15 ounce) can', 'crushed tomatoes'),
#  ('1', 'cup', 'sliced carrots'),
#  ('½', 'teaspoon', 'hot pepper sauce'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('2', 'tablespoons', 'water'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('1', 'tablespoon', 'fresh cilantro leaves'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('⅛', 'teaspoon', 'garlic powder'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('½', 'cup', 'vegetable oil'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('1', 'cup', 'plain yogurt'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('', '', 'salt to taste'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('1', 'tablespoon', 'chili powder'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('½', 'cup', 'heavy cream, heated'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('1', '', 'jalapeno pepper, finely chopped'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('2', 'teaspoons', 'paprika'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('1', 'cup', 'plain yogurt'),
#  ('1', '(8 ounce) can', 'sliced water chestnuts, drained'),
#  ('2', 'teaspoons', 'Worcestershire sauce'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('1', 'small', 'jalapeno pepper, cut into 1/16-inch-thick matchsticks'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('⅛', 'teaspoon', 'ground black pepper'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('¾', 'cup', 'coconut milk'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('½', 'teaspoon', 'salt (Optional)'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('2', 'teaspoons', 'paprika'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('1', 'tablespoon', 'vegetable oil'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('1', 'tablespoon', 'chopped fresh cilantro'),
#  ('1', '', 'green bell pepper, cut into matchsticks'),
#  ('1', 'teaspoon', 'file powder'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('1', 'wedge', 'lime'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('¼', 'cup', 'grated Parmesan cheese'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('½', '', 'lemon, juiced'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('8', '(10 inch)', 'flour tortillas'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('1', '(8 ounce) can', 'tomato sauce'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('4',
#   '',
#   'skinless, boneless chicken breast halves, cut into bite-size pieces'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('1', 'teaspoon', 'salt'),
#  (nan, nan, nan),
#  ('1 ¼', 'cups', 'uncooked white rice'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('½', 'teaspoon', 'cayenne pepper'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('1', '(12 ounce) jar', 'taco sauce'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('1', 'cup', 'heavy cream'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('½', 'teaspoon', 'curry powder'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('½', 'cup', 'water'),
#  (nan, nan, nan),
#  ('2 ½', 'cups', 'chicken broth'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ('¼', 'cup', 'chopped fresh cilantro'),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  (nan, nan, nan),
#  ...]

# %%
Ingredients_subset_df = pd.DataFrame(final_list,columns=["quantity","unit","name"])

# %%
Ingredients_subset_df.dropna(inplace=True)

# %%
cleaning(Ingredients_subset_df,"name","Name")
# Out:
#  Extracting ingredient for row 1121

# %%
Ingredients_subset_df
# Out:
#      quantity         unit                                      name  \
# 0           2       pounds  skinless, boneless chicken breast halves
# 1           4         cups                                     water
# 2           2  tablespoons                       peanut oil, divided
# 4           4    (5 ounce)  skinless, boneless chicken breast halves
# 5           ¼          cup             all-purpose flour for coating
# ...       ...          ...                                       ...
# 934         1          cup                               heavy cream
# 944         ½          cup                                     water
# 946       2 ½         cups                             chicken broth
# 1003        1     teaspoon                              garam masala
# 1121        1   tablespoon                         fresh lemon juice
#
#                     Name
# 0              skinless
# 1                 water
# 2            peanut oil
# 4              skinless
# 5         purpose flour
# ...                  ...
# 934         heavy cream
# 944               water
# 946       chicken broth
# 1003       garam masala
# 1121  fresh lemon juice
#
# [498 rows x 4 columns]

# %%
Ingredients_subset_df.drop(columns="name",inplace=True)

# %%
Ingredients_subset_df=Ingredients_subset_df.rename(columns={"Name": "name"})

# %%
total_ingre=pd.concat([df1,Ingredients_subset_df], axis=0)

# %%
total_ingre["unit"]=total_ingre["unit"].replace(["tablespoons", "pounds", "cups","ounces","fluid ounces","cloves","teaspoons"],["tablespoon", "pound", "cup","ounce","fluid ounce","clove","teaspoon"])

# %%
total_ingre
# Out:
#      quantity        unit                                   name
# 0         NaN  tablespoon  Smith apple Macintosh apple ice cream
# 1         NaN       small                            Smith apple
# 2         NaN         NaN                 peel cored white sugar
# 3         NaN         cup                          purpose apple
# 4         NaN         cup                            slice apple
# ...       ...         ...                                    ...
# 934         1         cup                           heavy cream
# 944         ½         cup                                 water
# 946       2 ½         cup                         chicken broth
# 1003        1    teaspoon                          garam masala
# 1121        1  tablespoon                     fresh lemon juice
#
# [1370 rows x 3 columns]

# %%
total_ingre["name"].value_counts().head(10)
# Out:
# white sugar      52
# purpose flour    49
# skinless         38
# salt             32
# butter           20
# black pepper     15
# egg              14
# olive oil        13
# garlic           12
# butter           12
# Name: name, dtype: int64

# %%
#The highest contributing ingredients are Sugar,salt,purpose flour
ingredient_counter = Counter(total_ingre["name"])
wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white").generate_from_frequencies(ingredient_counter)

plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
#Joining the recipe name and servings to the total_time
extra_col1= (df["recipe_name"],df["servings"])
extra_col2= (df2["Name"],df2["Servings"])

# %%
df_time1 = df1_recipes.join(extra_col1)
df_time2 = df2_recipes.join(extra_col2)

# %%
df_time2=df_time2.rename(columns={"Name": "recipe_name","Total Time": "total_time","Servings": "servings"})

# %%
df_time=pd.concat([df_time1,df_time2],axis=0)

# %%
df_time
# Out:
#     total_time                               recipe_name  servings
# 0            0                  Apple-Cranberry Crostada         8
# 1           90                 Apple Pie by Grandma Ople         8
# 2           25               Sarah's Homemade Applesauce         4
# 3           75                               Apple Crisp        12
# 4          160                         Apple Pie Filling        40
# ..         ...                                       ...       ...
# 54         435             Slow Cooker Chicken Taco Soup         8
# 55          80    Curry Stand Chicken Tikka Masala Sauce         6
# 56         280                                    Kabobs        10
# 57          40  Chef John's Homemade Chicken Noodle Soup         8
# 58          35             Broccoli and Chicken Stir-Fry         3
#
# [1020 rows x 3 columns]

# %%
top = df_time.sort_values(by=['total_time']).tail(40)
top
# Out:
#       total_time                                        recipe_name  servings
# 647          490                             Tropical Kiwi Ice Pops         6
# 959          495                                            Coquito        10
# 897          505  Cranberry Sauce with Apricots, Raisins, and Or...        24
# 319          510                       Raspberry Jam without Pectin        56
# 373          510                               White Peachy Sangria        20
# 1081         510              Great-Grandma Cathy's Date Loaf Candy        10
# 516          515                Holiday Cranberry-Pomegranate Sauce        24
# 907          515                                  Boozy Apricot Jam       144
# 188          515                                     Almond Tortoni         8
# 889          528                                 Apricot Cheesecake        12
# 705          540                       Pineapple Mango Habanero Jam        64
# 772          540                            Rosa Marina Fruit Salad        24
# 981          550                        Flan de Coco (Coconut Flan)        12
# 708          570          Coconut-Lime Cheesecake with Mango Coulis         8
# 759          570                        Instant Pot Tacos al Pastor        12
# 1066         575                   Ma'amoul (Lebanese Date Cookies)        48
# 1049         575               White Chocolate Raspberry Cheesecake        16
# 308          575                                     Frog Eye Salad        10
# 1012         580                   Overnight Blueberry French Toast        10
# 395          585                       Grandma's Peach French Toast         8
# 886          590                           Apricot-Glazed Pork Ribs        12
# 400          600                                Spicy Peach Chutney        96
# 546          640                            Spiced Persimmon Butter        64
# 23           640                               Amazing Apple Butter        48
# 186          645                        Crushed Pineapple Fruitcake        14
# 1028         660                              Strawberry Cheesecake        12
# 128          690                               All-Day Apple Butter       128
# 638          760                                           Kiwi Jam        40
# 424          765                           Grandma's Pear Preserves        48
# 366          790                    Nana's Southern Pickled Peaches        40
# 263          865                               Watermelon Preserves        40
# 239          935                        Momma's Fresh Fig Preserves        40
# 466         1135                                        Plum Butter        32
# 657         2965                   Char Siu (Chinese Barbeque Pork)         4
# 159        10165                             Old Time Mincemeat Pie         8
# 748        14410                            Pineapple-Infused Vodka        17
# 279        14475                              Watermelon Rind Candy       100
# 164        28392                          Door County Cherry Bounce        10
# 158        28502                         Thirty Day Friendship Cake        48
# 459        30300                                 Tangy Plum Liqueur        80

# %%
top["Cuisine"] = ""
for i, row in top.iterrows():
    top["Cuisine"][i] = df["Cuisines"][i]
top
# Out:
#       total_time                                        recipe_name  servings  \
# 647          490                             Tropical Kiwi Ice Pops         6
# 959          495                                            Coquito        10
# 897          505  Cranberry Sauce with Apricots, Raisins, and Or...        24
# 319          510                       Raspberry Jam without Pectin        56
# 373          510                               White Peachy Sangria        20
# 1081         510              Great-Grandma Cathy's Date Loaf Candy        10
# 516          515                Holiday Cranberry-Pomegranate Sauce        24
# 907          515                                  Boozy Apricot Jam       144
# 188          515                                     Almond Tortoni         8
# 889          528                                 Apricot Cheesecake        12
# 705          540                       Pineapple Mango Habanero Jam        64
# 772          540                            Rosa Marina Fruit Salad        24
# 981          550                        Flan de Coco (Coconut Flan)        12
# 708          570          Coconut-Lime Cheesecake with Mango Coulis         8
# 759          570                        Instant Pot Tacos al Pastor        12
# 1066         575                   Ma'amoul (Lebanese Date Cookies)        48
# 1049         575               White Chocolate Raspberry Cheesecake        16
# 308          575                                     Frog Eye Salad        10
# 1012         580                   Overnight Blueberry French Toast        10
# 395          585                       Grandma's Peach French Toast         8
# 886          590                           Apricot-Glazed Pork Ribs        12
# 400          600                                Spicy Peach Chutney        96
# 546          640                            Spiced Persimmon Butter        64
# 23           640                               Amazing Apple Butter        48
# 186          645                        Crushed Pineapple Fruitcake        14
# 1028         660                              Strawberry Cheesecake        12
# 128          690                               All-Day Apple Butter       128
# 638          760                                           Kiwi Jam        40
# 424          765                           Grandma's Pear Preserves        48
# 366          790                    Nana's Southern Pickled Peaches        40
# 263          865                               Watermelon Preserves        40
# 239          935                        Momma's Fresh Fig Preserves        40
# 466         1135                                        Plum Butter        32
# 657         2965                   Char Siu (Chinese Barbeque Pork)         4
# 159        10165                             Old Time Mincemeat Pie         8
# 748        14410                            Pineapple-Infused Vodka        17
# 279        14475                              Watermelon Rind Candy       100
# 164        28392                          Door County Cherry Bounce        10
# 158        28502                         Thirty Day Friendship Cake        48
# 459        30300                                 Tangy Plum Liqueur        80
#
#                    Cuisine
# 647               Desserts
# 959         Drinks Recipes
# 897              Side Dish
# 319              Side Dish
# 373         Drinks Recipes
# 1081              Desserts
# 516              Side Dish
# 907              Side Dish
# 188               Desserts
# 889               Desserts
# 705              Side Dish
# 772                  Salad
# 981               Desserts
# 708               Desserts
# 759            Main Dishes
# 1066        Middle Eastern
# 1049              Desserts
# 308                  Salad
# 1012  Breakfast and Brunch
# 395   Breakfast and Brunch
# 886       Meat and Poultry
# 400              Side Dish
# 546              Side Dish
# 23               Side Dish
# 186               Desserts
# 1028              Desserts
# 128              Side Dish
# 638              Side Dish
# 424              Side Dish
# 366              Side Dish
# 263              Side Dish
# 239              Side Dish
# 466              Side Dish
# 657                  Asian
# 159               Desserts
# 748         Drinks Recipes
# 279               Desserts
# 164         Drinks Recipes
# 158               Desserts
# 459         Drinks Recipes

# %%
#Dessert occures more frequently amoungst the top 40 time consuming recipes
sns.countplot(data=top, x="Cuisine", hue="Cuisine")
plt.title('Cuisine contributing to the highest total time amongst the top 40 time consuming recipes',fontdict={'fontsize': fontsize})
plt.xticks(rotation=90, ha='center')
plt.xlabel('Type of Cuisine')
plt.ylabel('total_count of cuisine')
# Out:
# Text(0, 0.5, 'total_count of cuisine')
